# %%
import cv2
import numpy as np
import pytesseract
import re
from bs4 import BeautifulSoup as soup
from Levenshtein import hamming, ratio, distance
from spellchecker import SpellChecker
from nltk import word_tokenize
import os, glob

# %%
def preprocess(img):
    """Crop and grayscale."""
    crop = img[100:4300, 100:2800]
    grayscaled = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)
    return grayscaled

def boundary_box(img):
    """Get boundary boxes of all ROIs in img."""
    blur = cv2.GaussianBlur(img, (15, 15), -1)
    thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    kernal_e = cv2.getStructuringElement(cv2.MORPH_RECT, (6, 2))
    kernal_d = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 6))
    erode = cv2.erode(thresh, kernal_e, iterations=1)
    dilate = cv2.dilate(erode, kernal_d, iterations=5)
    cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[0]
    cnts = sorted(cnts, key=lambda x: cv2.boundingRect(x)[0] + cv2.boundingRect(x)[1] * img.shape[1])
    
    rectangles = (cv2.minAreaRect(x) for x in cnts)
    boxes = []
    for rectangle in rectangles:
        box = np.int0(cv2.boxPoints(rectangle))
        by_y = sorted(box, key=lambda x: x[1])
        top, bottom = by_y[:2], by_y[2:]
        box = [*sorted(top, key=lambda x: x[0]),*sorted(bottom, key=lambda x: x[0], reverse=True),]
        box = np.array(box)
        boxes.append(box)
    # Sort by x-position
    boxes = sorted(boxes, key=lambda x: (cv2.moments(x)["m10"]/cv2.moments(x)["m00"]))
    # Sort by y-position
    boxes = sorted(boxes, key=lambda x: (cv2.moments(x)["m01"]/cv2.moments(x)["m00"]))
    return boxes

def extract_regions(boxes, ocr_img, lang_custom):
    """Extract desired regions"""
    ocr_results = []
    regions = []
    for n, box in enumerate(boxes):
        box = np.int0(box)
        width, height = get_box_parameters(box)
        if width > 500 and height > 170:
            # Starting region
            src_pts = box.astype("float32")
            # Destination region.
            dst_pts = np.array([[0, 0],[width - 1, 0],[width - 1, height - 1],[0, height - 1],],dtype="float32",)
            transform_matrix = cv2.getPerspectiveTransform(src_pts, dst_pts)
            warped = cv2.warpPerspective(ocr_img, transform_matrix, (width, height))            
            # https://docs.opencv.org/4.5.3/dc/da3/tutorial_copyMakeBorder.html
            white = [255]
            padded = cv2.copyMakeBorder(warped, 3, 3, 3, 3, cv2.BORDER_CONSTANT, value=white)
            # Save ROI images for diagnostics.
#             cv2.imwrite(f"Test/OCR Test/hOCRfile{i}_{n}.png", padded)
            regions.append(padded)
    return regions

def get_box_parameters(box):
    """Ensures bounding boxes are correctly oriented."""
    rect = cv2.minAreaRect(box)
    height = int(rect[1][1])
    width = int(rect[1][0])
    if abs(rect[2] - 90) < 45: 
        width, height = height, width
    return width, height

def ocr_image(grayscaled):
    """Prepare the input image for the OCR engine"""
    thresh, ocr_img = cv2.threshold(grayscaled, 240, 255, cv2.THRESH_TRUNC)
    return ocr_img

def ocr_region(region, work_name, i):
    """Perform OCR and save transcript as .html file in hOCR format."""
    ocr_result = pytesseract.image_to_pdf_or_hocr(region, lang = lang_custom, extension="hocr")
    with open(f"temp/{work_name}_hocr_{i}.html", "w+b") as f:
        f.write(ocr_result)
        print(f"File {work_name}_{i}.html saved.")
        
def thin_font(image):
    image = cv2.bitwise_not(image)
    kernel = np.ones((2,1),np.uint8)
    image = cv2.erode(image, kernel, iterations=1)
    image = cv2.bitwise_not(image)
    return (image)

def thick_font(image):
    image = cv2.bitwise_not(image)
    kernel = np.ones((2,1),np.uint8)
    image = cv2.dilate(image, kernel, iterations=1)
    image = cv2.bitwise_not(image)
    return (image)

def normalise_latin(string):
    """Normalise Latin language character set."""
    norm_string = re.sub("ã|à|ā|â", "a", string)
    norm_string = re.sub("è|ē|ę|ê", "e", norm_string)
    norm_string = re.sub("ì|ī|ĩ|î", "i", norm_string)
    norm_string = re.sub("ĳ", "ii", norm_string)
    norm_string = re.sub("õ|ò|ō|ô", "o", norm_string)
    norm_string = re.sub("ũ|ù|ū|û", "u", norm_string)
    norm_string = re.sub("đ", "d", norm_string)
    norm_string = re.sub("ǣ|ǽ|æ", "ae", norm_string)
    norm_string = re.sub("Æ", "AE", norm_string)
    norm_string = re.sub("œ", "oe", norm_string)
    norm_string = re.sub("Œ", "OE", norm_string)
    norm_string = re.sub("ſ", "s", norm_string)
    norm_string = re.sub("&", "et", norm_string)
    return norm_string

def normalise_greek(string):
    """Remove accidental variant Unicode forms."""
    norm_string = re.sub("\u03d0", "β", string)
    norm_string = re.sub("\u03d1", "θ", norm_string)
    norm_string = re.sub("\u03d2", "Υ", norm_string)
    norm_string = re.sub("\u03d5", "φ", norm_string)
    norm_string = re.sub("\u03d6", "π", norm_string)
    return norm_string

def remove_linebreaks(string):
    """Remove linebreaks and hyphenation from transcript."""
    norm_string = re.sub("\n", "", string)
    norm_string = re.sub("\r\n", "", norm_string)
    norm_string = re.sub("- ", "", norm_string)
    norm_string = re.sub("\|", "", norm_string)
    norm_string = re.sub(" (\.|,|;|:|!|\?)", "\g<1>", norm_string)
    return norm_string

def hocr_to_text(file_number, work_name):
    """Load and parse the hOCR file."""
    transcript_list = []
    for i in range(file_number):
        with open(f"temp/{work_name}_hocr_{i}.html", encoding = "utf-8") as f:
            hocr = soup(f, "html.parser")
        ocr_pars = hocr.find_all(class_="ocr_carea")
        for j, section in enumerate(ocr_pars):
            section = ocr_pars[j].get_text(" ",strip=True)
            if len(section) > 5:
                transcript_list.append(section)
    return transcript_list

def sequence_check(transcript_list):
    """Prints beginning and end of each section. Use to check ROIs are in correct order."""
    for i, section in enumerate(transcript_list):
        print(f"Section {i} length: {len(section)}\nSection {i} incipit: {section[0:60]}\nSection {i} explicit: {section[-60:]}\n=========")

def spell_check(text):
    """Tokenise transcript and run Pyspellcheck."""
    spell_checked = []
    tokens = word_tokenize(text)
    for token in tokens:
        if re.search("[A-Za-z]", token):
            token_corrected = spell_lat.correction(token)
            spell_checked.append(token_corrected)
            print(token, "\t → \t", token_corrected)
        elif re.search("[\u0370-\u1fff]", token):
            token_corrected = spell_grc.correction(token)
            spell_checked.append(token_corrected)
            print(token, "\t → \t", token_corrected)
    spell_checked = " ".join(spell_checked)
    return spell_checked

# %%
"""Set variables."""
pdf_number = "150"
work_name = "116-xenophon"
lang_custom = r"lat+grc_all"
folder_path = "input/"

"""Fetch input file names."""
pages = []
for filename in glob.glob(os.path.join(folder_path, f"{pdf_number}*?.png")):
    pages.append(filename)
print(pages)
# Out:
# ['input\\150 Xenophon-1.png', 'input\\150 Xenophon-2.png', 'input\\150 Xenophon-3.png', 'input\\150 Xenophon-4.png', 'input\\150 Xenophon-5.png', 'input\\150 Xenophon-6.png']

# %%
"""Run OCR program."""
regions = []
for i, page in enumerate(pages):
    file_string = pages[i]
    img = cv2.imread(file_string)
    grayscaled = preprocess(img)
    boxes = boundary_box(grayscaled)
    ocr_img = ocr_image(grayscaled)
    region = extract_regions(boxes, ocr_img, lang_custom)
    regions.append(region)
regions = [a for b in regions for a in b]
file_number = len(regions)
for i, region in enumerate(regions):
    ocr_region(region, work_name, i)
print("OCR finished.")
# Out:
# File 116-xenophon_0.html saved.
# File 116-xenophon_1.html saved.
# File 116-xenophon_2.html saved.
# File 116-xenophon_3.html saved.
# File 116-xenophon_4.html saved.
# File 116-xenophon_5.html saved.
# File 116-xenophon_6.html saved.
# File 116-xenophon_7.html saved.
# File 116-xenophon_8.html saved.
# File 116-xenophon_9.html saved.
# File 116-xenophon_10.html saved.
# File 116-xenophon_11.html saved.
# File 116-xenophon_12.html saved.
# File 116-xenophon_13.html saved.
# File 116-xenophon_14.html saved.
# File 116-xenophon_15.html saved.
# File 116-xenophon_16.html saved.
# File 116-xenophon_17.html saved.
# OCR finished.

# %%
transcript_list = hocr_to_text(file_number, work_name)
sequence_check(transcript_list)
# Out:
# Section 0 length: 3617
# Section 0 incipit: IMONIDES PoETA die quodam acceſſit ad Hieronem Tyrannum, Juu
# Section 0 explicit: me ſpoctatu dignas, ſiſdem licet accedere. Tyranni porro non
# =========
# Section 1 length: 3860
# Section 1 incipit: multum indulgent ſpectaculis, raroque interſunt, eo quod ipſ
# Section 1 explicit: odoribus, inquit Simonides, iſtis pretioſis quibus un- gimi-
# =========
# Section 2 length: 9
# Section 2 incipit: 645 Η 1Ὲ8
# Section 2 explicit: 645 Η 1Ὲ8
# =========
# Section 3 length: 4285
# Section 3 incipit: gimini, arbitror, eos plus boni capere, qui ſunt familiares,
# Section 3 explicit: irtute præſtantes, tum arma inſigniter pulera, mundum eximi-
# =========
# Section 4 length: 8
# Section 4 incipit: r Oæ 646
# Section 4 explicit: r Oæ 646
# =========
# Section 5 length: 4271
# Section 5 incipit: ſum uxoribus, ædes magnificentiſſimas, eaſque rebus pre- tio
# Section 5 explicit: icitias, quarum m ſunt Tyranni. Primum enim quoniam magnum \
# =========
# Section 6 length: 68
# Section 6 incipit: onum hominibus eſt amicitia, hoc conſideremus; Et- Tom. IV.
# Section 6 explicit: inibus eſt amicitia, hoc conſideremus; Et- Tom. IV. Sſæ enim
# =========
# Section 7 length: 6
# Section 7 incipit: 645 Hu
# Section 7 explicit: 645 Hu
# =========
# Section 8 length: 4285
# Section 8 incipit: gimini, arbitror, eos plus boni capere, qui ſunt familiares,
# Section 8 explicit: irtute præſtantes, tum arma inſigniter pulera, mundum eximi-
# =========
# Section 9 length: 9
# Section 9 incipit: rR ON 646
# Section 9 explicit: rR ON 646
# =========
# Section 10 length: 3096
# Section 10 incipit: ſum uxoribus, ædes magnificentiſſimas, eaſque rebus pre- tio
# Section 10 explicit: volũpta- tem, dum inimicos cogunt terga vertere, quantam dum
# =========
# Section 11 length: 1130
# Section 11 incipit: fugientes inſequuntur, quntam dum trucidant hoſtes. Quam ver
# Section 11 explicit: e per- ſpicuum facio. Nunc porro conſidera amicitias, quarum
# =========
# Section 12 length: 110
# Section 12 incipit: articipes ſunt Tyranni. Primum enim quoniam magnum onum homi
# Section 12 explicit:  onum hominibus eſt amicitia, hoc conſideremus; Et- Tom. IV.
# =========
# Section 13 length: 7
# Section 13 incipit: V : cnm
# Section 13 explicit: V : cnm
# =========
# Section 14 length: 14
# Section 14 incipit: 6c47 X E N O P
# Section 14 explicit: 6c47 X E N O P
# =========
# Section 15 length: 4333
# Section 15 incipit: enim quicumque videlicet diligitur ab aliquibus, amantes lib
# Section 15 explicit:  velint contrahere, quod idem Tyranno concęſſum non eſt. Nam
# =========
# Section 16 length: 11
# Section 16 incipit: ο ατι 5 648
# Section 16 explicit: ο ατι 5 648
# =========
# Section 17 length: 4293
# Section 17 incipit: maxima pars impendiorum maxime neceſſuriorum illis in corpor
# Section 17 explicit: llo- rum cuſtodum cuſtodes ſunt leges, itaque & pro ſeſe me-
# =========
# Section 18 length: 8
# Section 18 incipit: 649 H Iæ
# Section 18 explicit: 649 H Iæ
# =========
# Section 19 length: 4306
# Section 19 incipit: tuunt & pro vobis. Tyranni vero mercede conductos ha- bent ſ
# Section 19 explicit: mo- dum illo ſrui, poſtea hunc inore habent, vehentes laudi-
# =========
# Section 20 length: 9
# Section 20 incipit: REGOI 650
# Section 20 explicit: REGOI 650
# =========
# Section 21 length: 4320
# Section 21 incipit: bus, eumque ſpectant non aliter quam ſi ſuum quiſque bo- num
# Section 21 explicit: atum gerenti, etiam conductitio milite opus Tom. IV. Sſ3 eſ,
# =========
# Section 22 length: 10
# Section 22 incipit: 649 B rime
# Section 22 explicit: 649 B rime
# =========
# Section 23 length: 1969
# Section 23 incipit: tuunt & pro vobis. Tyranni vero mercede conductos ha- bent ſ
# Section 23 explicit: . Hæc ubi ex eo audiſſet Simonides, Videtur, inquit, Hieron,
# =========
# Section 24 length: 2286
# Section 24 incipit: præclara quædam eſſe res, honor, cujus amore mortales, & lab
# Section 24 explicit:  ido- neum qui poſſit benefacere, putentque ſuum eſſe commo-
# =========
# Section 25 length: 7
# Section 25 incipit: RrE O N
# Section 25 explicit: RrE O N
# =========
# Section 26 length: 2148
# Section 26 incipit: 650 bus, eumque ſpectant non aliter quam ſi ſuum quiſque bo-
# Section 26 explicit: - tus, hic expende uter paribus beneficiis plus initurus ſit
# =========
# Section 27 length: 55
# Section 27 incipit: D gratiæ. Ordiar autem ab exemplis infimis. Primum con-
# Section 27 explicit: D gratiæ. Ordiar autem ab exemplis infimis. Primum con-
# =========
# Section 28 length: 56
# Section 28 incipit: dum illo ſrui, poſtea hunc inore habent, vehentes laudi-
# Section 28 explicit: dum illo ſrui, poſtea hunc inore habent, vehentes laudi-
# =========
# Section 29 length: 2130
# Section 29 incipit: ſpectum aliquem ſalutet obvium amice, hinc Princeps, hinc pr
# Section 29 explicit: atum gerenti, etiam conductitio milite opus Tom. IV. Sſ3 eſ,
# =========
# Section 30 length: 14
# Section 30 incipit: Ηο κ τοῦ ς 652
# Section 30 explicit: Ηο κ τοῦ ς 652
# =========
# Section 31 length: 4425
# Section 31 incipit: Aaliqui facinoroſi in civitatibus. Itaque ſi fuerit imperatu
# Section 31 explicit: lenti hæc impertieris, quum omnes habiturus ſis tibi de tuis
# =========
# Section 32 length: 10
# Section 32 incipit: 651 Xænom:
# Section 32 explicit: 651 Xænom:
# =========
# Section 33 length: 4304
# Section 33 incipit: eſt. Qua quidem re non alia eſt ſarcina civibus gravior. Non
# Section 33 explicit: i quid tale ſenſerint. Sunt autem, quemadmodum ſcimus omnes,
# =========
# Section 34 length: 8
# Section 34 incipit: nr N 654
# Section 34 explicit: nr N 654
# =========
# Section 35 length: 394
# Section 35 incipit: ros, filios vero nonaliter habeas quam animam tuam , huc Int
# Section 35 explicit: quan- doquidem quum felix ſis , tamen tibi nullus invidebit.
# =========
# Section 36 length: 8
# Section 36 incipit: 653 ia -
# Section 36 explicit: 653 ia -
# =========
# Section 37 length: 402
# Section 37 incipit: tuis bonis gratulantes, omnes item non aliter pro tuis pri-
# Section 37 explicit:  tuam, cives vero ſodales, amicos exiſtima tuos ipſius libe-
# =========
# Section 38 length: 463
# Section 38 incipit: 3 IT TER æ tuæe, Vir ornatiſſime, quibus & pro tua prudentia
# Section 38 explicit: es. Et merebatur hoc quorumdam ſcurrilis improbitas, nec de-
# =========
# Section 39 length: 140
# Section 39 incipit: erant amici qui per litteras huc hortarentur. Bene vale, Vir
# Section 39 explicit: me. Friburgi v die Martii. Anno a Chriſtonatoo M D xXxXxXII.
# =========
# Section 40 length: 817
# Section 40 incipit: 653 H x2 ON 654 tuis bonis gratulantes, omnes item non alite
# Section 40 explicit: libe- ldoquidem quum felix ſis, tamen tibi nullus invidebit.
# =========
# Section 41 length: 10
# Section 41 incipit: 95rP NſIS.
# Section 41 explicit: 95rP NſIS.
# =========
# Section 42 length: 56
# Section 42 incipit: DE SIDE RIUS ERASMUS ROTERODAMUS CLARISSIMO LL. DOCT ORI
# Section 42 explicit: DE SIDE RIUS ERASMUS ROTERODAMUS CLARISSIMO LL. DOCT ORI
# =========
# Section 43 length: 19
# Section 43 incipit: J OANNI R I N C O,.
# Section 43 explicit: J OANNI R I N C O,.
# =========
# Section 44 length: 604
# Section 44 incipit: 3 ITTE R æ tuæ, Vir ornatiſſime, quibus & pro tua prudentia
# Section 44 explicit: ime. Friburgi v die Martii. Anno a Chriſtonatoo. M D XXXI1I.
# =========
# Section 45 length: 13
# Section 45 incipit: Ρ R E C A I O
# Section 45 explicit: Ρ R E C A I O
# =========
# Section 46 length: 56
# Section 46 incipit: D OMINU M J E S U M. Ρ 'O EEEAMIGCEE BECILIiEſĩSliitllæ.
# Section 46 explicit: D OMINU M J E S U M. Ρ 'O EEEAMIGCEE BECILIiEſĩSliitllæ.
# =========
# Section 47 length: 744
# Section 47 incipit: OMINE Jeſu Chriſte, qui pro tua gloriæ perpetuo glorientur d
# Section 47 explicit: uxa-1]ad vocem tuam omnipotentem, ſubſedere fſluctus, conſi-
# =========
# Section 48 length: 446
# Section 48 incipit: ta, reformas collapſa, mortua revificas, dignare quæſu-1 uer
# Section 48 explicit: ra cœ- tantur non paucorum corpora, ſed innumerabiles animæ,
# =========
# Section 49 length: 1037
# Section 49 incipit: Ios infraque terras ſunt, flectere digneris oculos illos mit
# Section 49 explicit: s tot ſunt Hominum millia, qui diligunt nominis tui gloriam,
# =========
# Section 50 length: 891
# Section 50 incipit: Juctetur tua navicula, extra quam nulli vis eſſe ſalutem. qu
# Section 50 explicit: um res quamlibet diſcordes redigis in concordiam, unicus pa-
# =========
# Section 51 length: 1482
# Section 51 incipit: ac peſtilentiarum generibus adſlicti, tot inundationibus ci8
# Section 51 explicit: rannidem exerceant impune? Patieris illum fortem, quem ſemel
# =========
# Section 52 length: 2190
# Section 52 incipit: omnipotentia condidiſti creaturam omnem viſibilem pariter &
# Section 52 explicit:  Turcæ, ac cæteri, qui vel non noverunt te, vel invident tuæ
# =========
# Section 53 length: 2353
# Section 53 incipit: gloriæ perpetuo glorientur de nobis, dicantque, ubi eſt Deus
# Section 53 explicit: rannidem exerceant impune? Patieris illum fortem, quem ſemel
# =========

# %%
"""Commands for ammending transcript ordering and removing noise."""
print("Original length: ",len(transcript_list))
# Change order
transcript_list[6], transcript_list[7] = transcript_list[7], transcript_list[6]
transcript_list[13], transcript_list[16] = transcript_list[16], transcript_list[13]
transcript_list[18], transcript_list[17] = transcript_list[17], transcript_list[18]
transcript_list[19], transcript_list[23] = transcript_list[23], transcript_list[19]
transcript_list[26], transcript_list[29] = transcript_list[29], transcript_list[26]
transcript_list[36], transcript_list[38] = transcript_list[38], transcript_list[36]
transcript_list[47], transcript_list[46] = transcript_list[46], transcript_list[47]
transcript_list[81], transcript_list[80] = transcript_list[80], transcript_list[81]
transcript_list[87], transcript_list[86] = transcript_list[86], transcript_list[87]
print("New length: ",len(transcript_list))
# Remove noise
del transcript_list[34]
del transcript_list[32]
del transcript_list[30]
del transcript_list[28]
del transcript_list[27]
del transcript_list[25]
del transcript_list[20]
del transcript_list[18]
del transcript_list[16]
del transcript_list[14]
del transcript_list[13]
del transcript_list[9]
del transcript_list[6]
del transcript_list[4]
del transcript_list[2]
print("New length: ",len(transcript_list))
# Out:
# Original length:  54
# New length:  54
# New length:  39

# %%
sequence_check(transcript_list)
# Out:
# Section 0 length: 3617
# Section 0 incipit: IMONIDES PoETA die quodam acceſſit ad Hieronem Tyrannum, Juu
# Section 0 explicit: me ſpoctatu dignas, ſiſdem licet accedere. Tyranni porro non
# =========
# Section 1 length: 3860
# Section 1 incipit: multum indulgent ſpectaculis, raroque interſunt, eo quod ipſ
# Section 1 explicit: odoribus, inquit Simonides, iſtis pretioſis quibus un- gimi-
# =========
# Section 2 length: 4285
# Section 2 incipit: gimini, arbitror, eos plus boni capere, qui ſunt familiares,
# Section 2 explicit: irtute præſtantes, tum arma inſigniter pulera, mundum eximi-
# =========
# Section 3 length: 4271
# Section 3 incipit: ſum uxoribus, ædes magnificentiſſimas, eaſque rebus pre- tio
# Section 3 explicit: icitias, quarum m ſunt Tyranni. Primum enim quoniam magnum \
# =========
# Section 4 length: 6
# Section 4 incipit: 645 Hu
# Section 4 explicit: 645 Hu
# =========
# Section 5 length: 4285
# Section 5 incipit: gimini, arbitror, eos plus boni capere, qui ſunt familiares,
# Section 5 explicit: irtute præſtantes, tum arma inſigniter pulera, mundum eximi-
# =========
# Section 6 length: 3096
# Section 6 incipit: ſum uxoribus, ædes magnificentiſſimas, eaſque rebus pre- tio
# Section 6 explicit: volũpta- tem, dum inimicos cogunt terga vertere, quantam dum
# =========
# Section 7 length: 1130
# Section 7 incipit: fugientes inſequuntur, quntam dum trucidant hoſtes. Quam ver
# Section 7 explicit: e per- ſpicuum facio. Nunc porro conſidera amicitias, quarum
# =========
# Section 8 length: 110
# Section 8 incipit: articipes ſunt Tyranni. Primum enim quoniam magnum onum homi
# Section 8 explicit:  onum hominibus eſt amicitia, hoc conſideremus; Et- Tom. IV.
# =========
# Section 9 length: 4333
# Section 9 incipit: enim quicumque videlicet diligitur ab aliquibus, amantes lib
# Section 9 explicit:  velint contrahere, quod idem Tyranno concęſſum non eſt. Nam
# =========
# Section 10 length: 4293
# Section 10 incipit: maxima pars impendiorum maxime neceſſuriorum illis in corpor
# Section 10 explicit: llo- rum cuſtodum cuſtodes ſunt leges, itaque & pro ſeſe me-
# =========
# Section 11 length: 4306
# Section 11 incipit: tuunt & pro vobis. Tyranni vero mercede conductos ha- bent ſ
# Section 11 explicit: mo- dum illo ſrui, poſtea hunc inore habent, vehentes laudi-
# =========
# Section 12 length: 4320
# Section 12 incipit: bus, eumque ſpectant non aliter quam ſi ſuum quiſque bo- num
# Section 12 explicit: atum gerenti, etiam conductitio milite opus Tom. IV. Sſ3 eſ,
# =========
# Section 13 length: 10
# Section 13 incipit: 649 B rime
# Section 13 explicit: 649 B rime
# =========
# Section 14 length: 1969
# Section 14 incipit: tuunt & pro vobis. Tyranni vero mercede conductos ha- bent ſ
# Section 14 explicit: . Hæc ubi ex eo audiſſet Simonides, Videtur, inquit, Hieron,
# =========
# Section 15 length: 2286
# Section 15 incipit: præclara quædam eſſe res, honor, cujus amore mortales, & lab
# Section 15 explicit:  ido- neum qui poſſit benefacere, putentque ſuum eſſe commo-
# =========
# Section 16 length: 2148
# Section 16 incipit: 650 bus, eumque ſpectant non aliter quam ſi ſuum quiſque bo-
# Section 16 explicit: - tus, hic expende uter paribus beneficiis plus initurus ſit
# =========
# Section 17 length: 2130
# Section 17 incipit: ſpectum aliquem ſalutet obvium amice, hinc Princeps, hinc pr
# Section 17 explicit: atum gerenti, etiam conductitio milite opus Tom. IV. Sſ3 eſ,
# =========
# Section 18 length: 4425
# Section 18 incipit: Aaliqui facinoroſi in civitatibus. Itaque ſi fuerit imperatu
# Section 18 explicit: lenti hæc impertieris, quum omnes habiturus ſis tibi de tuis
# =========
# Section 19 length: 4304
# Section 19 incipit: eſt. Qua quidem re non alia eſt ſarcina civibus gravior. Non
# Section 19 explicit: i quid tale ſenſerint. Sunt autem, quemadmodum ſcimus omnes,
# =========
# Section 20 length: 394
# Section 20 incipit: ros, filios vero nonaliter habeas quam animam tuam , huc Int
# Section 20 explicit: quan- doquidem quum felix ſis , tamen tibi nullus invidebit.
# =========
# Section 21 length: 8
# Section 21 incipit: 653 ia -
# Section 21 explicit: 653 ia -
# =========
# Section 22 length: 402
# Section 22 incipit: tuis bonis gratulantes, omnes item non aliter pro tuis pri-
# Section 22 explicit:  tuam, cives vero ſodales, amicos exiſtima tuos ipſius libe-
# =========
# Section 23 length: 463
# Section 23 incipit: 3 IT TER æ tuæe, Vir ornatiſſime, quibus & pro tua prudentia
# Section 23 explicit: es. Et merebatur hoc quorumdam ſcurrilis improbitas, nec de-
# =========
# Section 24 length: 140
# Section 24 incipit: erant amici qui per litteras huc hortarentur. Bene vale, Vir
# Section 24 explicit: me. Friburgi v die Martii. Anno a Chriſtonatoo M D xXxXxXII.
# =========
# Section 25 length: 817
# Section 25 incipit: 653 H x2 ON 654 tuis bonis gratulantes, omnes item non alite
# Section 25 explicit: libe- ldoquidem quum felix ſis, tamen tibi nullus invidebit.
# =========
# Section 26 length: 10
# Section 26 incipit: 95rP NſIS.
# Section 26 explicit: 95rP NſIS.
# =========
# Section 27 length: 56
# Section 27 incipit: DE SIDE RIUS ERASMUS ROTERODAMUS CLARISSIMO LL. DOCT ORI
# Section 27 explicit: DE SIDE RIUS ERASMUS ROTERODAMUS CLARISSIMO LL. DOCT ORI
# =========
# Section 28 length: 19
# Section 28 incipit: J OANNI R I N C O,.
# Section 28 explicit: J OANNI R I N C O,.
# =========
# Section 29 length: 604
# Section 29 incipit: 3 ITTE R æ tuæ, Vir ornatiſſime, quibus & pro tua prudentia
# Section 29 explicit: ime. Friburgi v die Martii. Anno a Chriſtonatoo. M D XXXI1I.
# =========
# Section 30 length: 13
# Section 30 incipit: Ρ R E C A I O
# Section 30 explicit: Ρ R E C A I O
# =========
# Section 31 length: 56
# Section 31 incipit: D OMINU M J E S U M. Ρ 'O EEEAMIGCEE BECILIiEſĩSliitllæ.
# Section 31 explicit: D OMINU M J E S U M. Ρ 'O EEEAMIGCEE BECILIiEſĩSliitllæ.
# =========
# Section 32 length: 744
# Section 32 incipit: OMINE Jeſu Chriſte, qui pro tua gloriæ perpetuo glorientur d
# Section 32 explicit: uxa-1]ad vocem tuam omnipotentem, ſubſedere fſluctus, conſi-
# =========
# Section 33 length: 446
# Section 33 incipit: ta, reformas collapſa, mortua revificas, dignare quæſu-1 uer
# Section 33 explicit: ra cœ- tantur non paucorum corpora, ſed innumerabiles animæ,
# =========
# Section 34 length: 1037
# Section 34 incipit: Ios infraque terras ſunt, flectere digneris oculos illos mit
# Section 34 explicit: s tot ſunt Hominum millia, qui diligunt nominis tui gloriam,
# =========
# Section 35 length: 891
# Section 35 incipit: Juctetur tua navicula, extra quam nulli vis eſſe ſalutem. qu
# Section 35 explicit: um res quamlibet diſcordes redigis in concordiam, unicus pa-
# =========
# Section 36 length: 1482
# Section 36 incipit: ac peſtilentiarum generibus adſlicti, tot inundationibus ci8
# Section 36 explicit: rannidem exerceant impune? Patieris illum fortem, quem ſemel
# =========
# Section 37 length: 2190
# Section 37 incipit: omnipotentia condidiſti creaturam omnem viſibilem pariter &
# Section 37 explicit:  Turcæ, ac cæteri, qui vel non noverunt te, vel invident tuæ
# =========
# Section 38 length: 2353
# Section 38 incipit: gloriæ perpetuo glorientur de nobis, dicantque, ubi eſt Deus
# Section 38 explicit: rannidem exerceant impune? Patieris illum fortem, quem ſemel
# =========

# %%
transcript = " ".join(transcript_list)
transcript = normalise_latin(transcript)
transcript = normalise_greek(transcript)
transcript = remove_linebreaks(transcript)
with open(f"temp/{work_name}_transcript.txt", "w", encoding = "utf-8") as f:
    f.write(transcript)
    print(f"File {work_name}_transcript.txt saved.")
# Out:
# File 116-xenophon_transcript.txt saved.

# %% [markdown]
# Postprocessing

# %%
"""Load Latin and Greek frequency lists."""
spell_lat = SpellChecker(local_dictionary="latin_freq.json")
spell_grc = SpellChecker(local_dictionary="greek_freq.json")

# %%
with open(f"temp/{work_name}_transcript.txt", "r", encoding = "utf-8") as f:
    text = f.read()
spell_checked = spell_check(text)
spell_checked_2 = re.sub(" (\.|,|;|:|\?|\!|·|;)", "\g<1>", spell_checked)
with open(f"output/{work_name}_spellcheck.txt", "w", encoding = "utf-8") as f:
    f.write(spell_checked_2)
    print(f"File {work_name}_spellcheck.txt saved.")
# Out:
# Xenophontis 	 → 	 Xenophontis
# Rhetoris 	 → 	 Rhetoris
# Hieron 	 → 	 Hieron
# sive 	 → 	 sive
# Tyrannus 	 → 	 Tyrannus
# Desiderio 	 → 	 Desiderio
# Erasmo 	 → 	 Erasmo
# Roterodamo 	 → 	 roterodamus
# interprete 	 → 	 interprete
# Simonides 	 → 	 Simonides
# poeta 	 → 	 poeta
# die 	 → 	 die
# quodam 	 → 	 quodam
# accessit 	 → 	 accessit
# ad 	 → 	 ad
# Hieronem 	 → 	 Hieronem
# Tyrannum 	 → 	 Tyrannum
# Juumque 	 → 	 quumque
# otium 	 → 	 otium
# forte 	 → 	 forte
# esset 	 → 	 esset
# utrisque 	 → 	 utrisque
# Simonides 	 → 	 Simonides
# hunc 	 → 	 hunc
# in 	 → 	 in
# modum 	 → 	 modum
# locutus 	 → 	 locutus
# cst 	 → 	 est
# Vellesne 	 → 	 vellent
# mihi 	 → 	 mihi
# explicare 	 → 	 explicare
# Hieron 	 → 	 Hieron
# ῃ 	 → 	 ὁ
# v 	 → 	 v
# ea 	 → 	 ea
# quae 	 → 	 quae
# probabile 	 → 	 probabile
# est 	 → 	 est
# te 	 → 	 te
# melius 	 → 	 melius
# nosse 	 → 	 nosse
# ah 	 → 	 ah
# quam 	 → 	 quam
# ego 	 → 	 ego
# novi 	 → 	 novi
# Et 	 → 	 Et
# quaenam 	 → 	 quaenam
# inquit 	 → 	 inquit
# Hieron 	 → 	 Hieron
# sunt 	 → 	 sunt
# ista 	 → 	 ista
# quae 	 → 	 quae
# mihi 	 → 	 mihi
# notiora 	 → 	 notiora
# possint 	 → 	 possint
# esse 	 → 	 esse
# quam 	 → 	 quam
# tibi 	 → 	 tibi
# viro 	 → 	 viro
# tam 	 → 	 tam
# erudito 	 → 	 erudito
# tantaque 	 → 	 tantaque
# sapientia 	 → 	 sapientia
# praedito 	 → 	 praedito
# Novi 	 → 	 Novi
# inquit 	 → 	 inquit
# te 	 → 	 te
# cum 	 → 	 cum
# esses 	 → 	 esses
# privatus 	 → 	 privatus
# et 	 → 	 et
# nunc 	 → 	 nunc
# regno 	 → 	 regno
# potientem 	 → 	 potentem
# novi 	 → 	 novi
# cum 	 → 	 cum
# igitur 	 → 	 igitur
# utrumque 	 → 	 utrumque
# vitae 	 → 	 vitae
# genus 	 → 	 genus
# sis 	 → 	 sis
# expertus 	 → 	 expertus
# verisimile 	 → 	 verisimile
# est 	 → 	 est
# hinc 	 → 	 hinc
# te 	 → 	 te
# nosse 	 → 	 nosse
# melius 	 → 	 melius
# me 	 → 	 me
# quid 	 → 	 quid
# discriminis 	 → 	 discriminis
# sit 	 → 	 sit
# inter 	 → 	 inter
# vitam 	 → 	 vitam
# Regiam 	 → 	 Regiam
# et 	 → 	 et
# inter 	 → 	 inter
# privatam 	 → 	 privatam
# quantum 	 → 	 quantum
# attinet 	 → 	 attinet
# ad 	 → 	 ad
# ea 	 → 	 ea
# quae 	 → 	 quae
# vel 	 → 	 vel
# voluptatem 	 → 	 voluptatem
# vel 	 → 	 vel
# molestiam 	 → 	 molestiam
# adferunt 	 → 	 adferunt
# hominibus 	 → 	 hominibus
# Quintu 	 → 	 quinto
# igitur 	 → 	 igitur
# inquit 	 → 	 inquit
# Hieron 	 → 	 Hieron
# quoniam 	 → 	 quoniam
# nunc 	 → 	 nunc
# adhuc 	 → 	 adhuc
# sane 	 → 	 sane
# privatam 	 → 	 privatam
# agis 	 → 	 agis
# vitam 	 → 	 vitam
# commonefacis 	 → 	 commonefacis
# me 	 → 	 me
# commodorum 	 → 	 commodorum
# et 	 → 	 et
# incommodorum 	 → 	 incommodorum
# quae 	 → 	 quae
# in 	 → 	 in
# privata 	 → 	 privata
# accidunt 	 → 	 accidunt
# vita 	 → 	 vita
# Sic 	 → 	 Sic
# enim 	 → 	 enim
# tibi 	 → 	 tibi
# ut 	 → 	 ut
# arbitror 	 → 	 arbitror
# maxime 	 → 	 maxime
# potero 	 → 	 potero
# quid 	 → 	 quid
# inter 	 → 	 inter
# hanc 	 → 	 hanc
# et 	 → 	 et
# illam 	 → 	 illam
# intersit 	 → 	 intersit
# explicare 	 → 	 explicare
# Ad 	 → 	 Ad
# quae 	 → 	 quae
# hunc 	 → 	 hunc
# in 	 → 	 in
# modum 	 → 	 modum
# Simonides 	 → 	 Simonides
# respondit 	 → 	 respondit
# Equidem 	 → 	 Equidem
# mihi 	 → 	 mihi
# videor 	 → 	 videor
# hoc 	 → 	 hoc
# animadvertisse 	 → 	 animadvertisse
# Hieron 	 → 	 Hieron
# homines 	 → 	 homines
# privatam 	 → 	 privatam
# agentes 	 → 	 agentes
# vitam 	 → 	 vitam
# vel 	 → 	 vel
# voluptate 	 → 	 voluptate
# vel 	 → 	 vel
# dolore 	 → 	 dolore
# adfici 	 → 	 adfici
# per 	 → 	 per
# oculos 	 → 	 oculos
# quidem 	 → 	 quidem
# iis 	 → 	 iis
# rebus 	 → 	 rebus
# quae 	 → 	 quae
# cernuntur 	 → 	 cernuntur
# per 	 → 	 per
# aures 	 → 	 aures
# autem 	 → 	 autem
# iis 	 → 	 iis
# quae 	 → 	 quae
# audiuntur 	 → 	 audiuntur
# per 	 → 	 per
# nares 	 → 	 nares
# item 	 → 	 item
# iis 	 → 	 iis
# quae 	 → 	 quae
# olfactu 	 → 	 olfactu
# sentiuntur 	 → 	 sentiuntur
# per 	 → 	 per
# os 	 → 	 os
# vero 	 → 	 vero
# tum 	 → 	 tum
# esculentis 	 → 	 esculentis
# tum 	 → 	 tum
# poculis 	 → 	 poculis
# Ea 	 → 	 Ea
# porro 	 → 	 porro
# quae 	 → 	 quae
# spectant 	 → 	 spectant
# ad 	 → 	 ad
# rem 	 → 	 rem
# Veneream 	 → 	 venerem
# his 	 → 	 his
# corporis 	 → 	 corporis
# partibus 	 → 	 partibus
# sentiuntur 	 → 	 sentiuntur
# quas 	 → 	 quas
# novimus 	 → 	 novimus
# omnes 	 → 	 omnes
# Tum 	 → 	 Tum
# frigida 	 → 	 frigida
# calidaque 	 → 	 calidique
# dura 	 → 	 dura
# et 	 → 	 et
# mollia 	 → 	 mollia
# levia 	 → 	 levia
# et 	 → 	 et
# ravia 	 → 	 avia
# toto 	 → 	 toto
# corpore 	 → 	 corpore
# videmur 	 → 	 videmur
# inquit 	 → 	 inquit
# dijudicare 	 → 	 diiudicare
# atque 	 → 	 atque
# ex 	 → 	 ex
# illorum 	 → 	 illorum
# sensu 	 → 	 sensu
# vel 	 → 	 vel
# delectationem 	 → 	 delectationem
# vel 	 → 	 vel
# molestiam 	 → 	 molestiam
# percipere 	 → 	 percipere
# Porro 	 → 	 Porro
# malis 	 → 	 malis
# ac 	 → 	 ac
# bonis 	 → 	 bonis
# interdum 	 → 	 interdum
# per 	 → 	 per
# ipsum 	 → 	 ipsum
# animum 	 → 	 animum
# ut 	 → 	 ut
# mihi 	 → 	 mihi
# videtur 	 → 	 videtur
# asficimur 	 → 	 afficimur
# dum 	 → 	 dum
# his 	 → 	 his
# delectamur 	 → 	 delectamur
# illis 	 → 	 illis
# offendimur 	 → 	 offendimur
# nonnumquam 	 → 	 nonnumquam
# per 	 → 	 per
# utrumque 	 → 	 utrumque
# communiter 	 → 	 communiter
# hoc 	 → 	 hoc
# est 	 → 	 est
# per 	 → 	 per
# animam 	 → 	 animam
# simul 	 → 	 simul
# et 	 → 	 et
# per 	 → 	 per
# corpus 	 → 	 corpus
# Jam 	 → 	 Jam
# mihi 	 → 	 mihi
# videor 	 → 	 videor
# utcumque 	 → 	 utcumque
# intelligere 	 → 	 intelligere
# somno 	 → 	 somno
# delectamur 	 → 	 delectamur
# verum 	 → 	 verum
# id 	 → 	 id
# quo 	 → 	 quo
# pacto 	 → 	 pacto
# aut 	 → 	 aut
# per 	 → 	 per
# quid 	 → 	 quid
# aut 	 → 	 aut
# quando 	 → 	 quando
# fiat 	 → 	 fiat
# haec 	 → 	 haec
# mihi 	 → 	 mihi
# videor 	 → 	 videor
# nescire 	 → 	 nescire
# potius 	 → 	 potius
# quam 	 → 	 quam
# scire 	 → 	 scire
# quomodo 	 → 	 quomodo
# sese 	 → 	 sese
# habeant 	 → 	 habeant
# Nec 	 → 	 Nec
# id 	 → 	 id
# forte 	 → 	 forte
# mirandum 	 → 	 mirandum
# si 	 → 	 si
# quae 	 → 	 quae
# nobis 	 → 	 nobis
# vigilantibus 	 → 	 vigilantibus
# accidunt 	 → 	 accidunt
# sensum 	 → 	 sensum
# sui 	 → 	 sui
# praebent 	 → 	 praebent
# evidentiorem 	 → 	 eminentiorem
# quam 	 → 	 quam
# ea 	 → 	 ea
# quae 	 → 	 quae
# in 	 → 	 in
# somnis 	 → 	 somnis
# obveniunt 	 → 	 obveniunt
# Ad 	 → 	 Ad
# haec 	 → 	 haec
# Hieron 	 → 	 Hieron
# hunc 	 → 	 hunc
# in 	 → 	 in
# modum 	 → 	 modum
# respondit 	 → 	 respondit
# Ego 	 → 	 Ego
# sane 	 → 	 sane
# Simonides 	 → 	 Simonides
# haudquaquam 	 → 	 haudquaquam
# dicere 	 → 	 dicere
# possim 	 → 	 possim
# quomodo 	 → 	 quomodo
# Rex 	 → 	 Rex
# ulla 	 → 	 ulla
# alia 	 → 	 alia
# re 	 → 	 re
# possit 	 → 	 possit
# adfici 	 → 	 adfici
# praeter 	 → 	 praeter
# haec 	 → 	 haec
# quae 	 → 	 quae
# commemorasti 	 → 	 commemorati
# Itaque 	 → 	 Itaque
# hactenus 	 → 	 hactenus
# sane 	 → 	 sane
# non 	 → 	 non
# intelligo 	 → 	 intelligo
# qua 	 → 	 qua
# re 	 → 	 re
# vita 	 → 	 vita
# Regia 	 → 	 Regia
# privatam 	 → 	 privatam
# antecedat 	 → 	 antecedat
# Tum 	 → 	 Tum
# Simonides 	 → 	 Simonides
# Atqui 	 → 	 Atqui
# in 	 → 	 in
# his 	 → 	 his
# tamen 	 → 	 tamen
# inquit 	 → 	 inquit
# discrimen 	 → 	 discrimen
# est 	 → 	 est
# Nam 	 → 	 Nam
# ex 	 → 	 ex
# horum 	 → 	 horum
# unoquoque 	 → 	 unoquoque
# Rex 	 → 	 Rex
# ut 	 → 	 ut
# multis 	 → 	 multis
# partibus 	 → 	 partibus
# majorem 	 → 	 majorem
# capit 	 → 	 capit
# voluptatem 	 → 	 voluptatem
# sic 	 → 	 sic
# ex 	 → 	 ex
# iisdem 	 → 	 iisdem
# minus 	 → 	 minus
# habet 	 → 	 habet
# molestiarum 	 → 	 molestiarum
# Ad 	 → 	 Ad
# haec 	 → 	 haec
# Hieron 	 → 	 Hieron
# Non 	 → 	 Non
# ita 	 → 	 ita
# inquit 	 → 	 inquit
# ut 	 → 	 ut
# dicis 	 → 	 dicis
# res 	 → 	 res
# habet 	 → 	 habet
# o 	 → 	 o
# Simonides 	 → 	 Simonides
# Quin 	 → 	 Quin
# potius 	 → 	 potius
# islud 	 → 	 illud
# scito 	 → 	 scito
# Regem 	 → 	 Regem
# ex 	 → 	 ex
# hisce 	 → 	 hisce
# rebus 	 → 	 rebus
# ut 	 → 	 ut
# longe 	 → 	 longe
# minorem 	 → 	 minorem
# capere 	 → 	 capere
# voluptatem 	 → 	 voluptatem
# quam 	 → 	 quam
# privati 	 → 	 privati
# capiunt 	 → 	 capiunt
# qui 	 → 	 qui
# mediocri 	 → 	 mediocri
# fortuna 	 → 	 fortuna
# sunt 	 → 	 sunt
# ita 	 → 	 ita
# longe 	 → 	 longe
# plus 	 → 	 plus
# auferre 	 → 	 auferre
# molestiarum 	 → 	 molestiarum
# Incredibilia 	 → 	 Incredibilia
# narras 	 → 	 narras
# ait 	 → 	 ait
# Simonides 	 → 	 Simonides
# Nam 	 → 	 Nam
# si 	 → 	 si
# ita 	 → 	 ita
# esset 	 → 	 esset
# ut 	 → 	 ut
# narras 	 → 	 narras
# qui 	 → 	 qui
# factum 	 → 	 factum
# est 	 → 	 est
# ur 	 → 	 ur
# multi 	 → 	 multi
# regnum 	 → 	 regnum
# adfectarint 	 → 	 adfectant
# praesertim 	 → 	 praesertim
# ex 	 → 	 ex
# eorum 	 → 	 eorum
# numero 	 → 	 numero
# ui 	 → 	 ui
# videbantur 	 → 	 videbantur
# esse 	 → 	 esse
# viri 	 → 	 viri
# ea 	 → 	 ea
# conditione 	 → 	 conditione
# ut 	 → 	 ut
# maxime 	 → 	 maxime
# sua 	 → 	 sua
# sorte 	 → 	 sorte
# ebuerint 	 → 	 debuerint
# esse 	 → 	 esse
# contenti 	 → 	 contenti
# Rursus 	 → 	 Rursus
# qui 	 → 	 qui
# fieret 	 → 	 fieret
# ut 	 → 	 ut
# omnes 	 → 	 omnes
# Tyrannis 	 → 	 Tyrannis
# invideant 	 → 	 invideant
# Tum 	 → 	 Tum
# Hieron 	 → 	 Hieron
# Quoniam 	 → 	 Quoniam
# inquit 	 → 	 inquit
# per 	 → 	 per
# Jovem 	 → 	 Jovem
# vitam 	 → 	 vitam
# utramque 	 → 	 utramque
# non 	 → 	 non
# sunt 	 → 	 sunt
# experti 	 → 	 experti
# ideo 	 → 	 ideo
# sic 	 → 	 sic
# judicant 	 → 	 judicant
# de 	 → 	 de
# negotio 	 → 	 negotio
# At 	 → 	 At
# ego 	 → 	 ego
# conabor 	 → 	 conabor
# tibi 	 → 	 tibi
# declarare 	 → 	 declarare
# me 	 → 	 me
# vera 	 → 	 vera
# loqui 	 → 	 loqui
# orsus 	 → 	 orsus
# a 	 → 	 ad
# visu 	 → 	 visu
# quandoquidem 	 → 	 quandoquidem
# tu 	 → 	 tu
# quoque 	 → 	 quoque
# ut 	 → 	 ut
# meminisse 	 → 	 meminisse
# mihi 	 → 	 mihi
# videor 	 → 	 videor
# ab 	 → 	 ab
# hoc 	 → 	 hoc
# ipso 	 → 	 ipso
# sermonem 	 → 	 sermonem
# ordiebaris 	 → 	 oriebaris
# Primum 	 → 	 Primum
# igitur 	 → 	 igitur
# quum 	 → 	 quum
# reputo 	 → 	 reputo
# quid 	 → 	 quid
# adferant 	 → 	 adferant
# voluptatis 	 → 	 voluptatis
# quae 	 → 	 quae
# cernuntur 	 → 	 cernuntur
# oculis 	 → 	 oculis
# comperio 	 → 	 comperio
# Tyrannos 	 → 	 Tyrannos
# deterius 	 → 	 deterius
# habere 	 → 	 habere
# quam 	 → 	 quam
# privatos 	 → 	 privatos
# homines 	 → 	 homines
# In 	 → 	 In
# aliis 	 → 	 aliis
# quidem 	 → 	 quidem
# atque 	 → 	 atque
# aliis 	 → 	 aliis
# regionibus 	 → 	 regionibus
# alia 	 → 	 alia
# atque 	 → 	 atque
# alia 	 → 	 alia
# sunt 	 → 	 sunt
# spectatu 	 → 	 spectat
# digna 	 → 	 digna
# Ad 	 → 	 Ad
# haec 	 → 	 haec
# vero 	 → 	 vero
# spectacula 	 → 	 spectacula
# omnia 	 → 	 omnia
# proficiscuntur 	 → 	 proficiscuntur
# privati 	 → 	 privati
# inque 	 → 	 inque
# civitates 	 → 	 civitates
# quascumque 	 → 	 quascumque
# voluerint 	 → 	 voluerint
# se 	 → 	 se
# conferunt 	 → 	 conferunt
# spectandi 	 → 	 spectandi
# gratia 	 → 	 gratia
# quod 	 → 	 quod
# in 	 → 	 in
# quaque 	 → 	 quaque
# visendum 	 → 	 visendum
# est 	 → 	 est
# Tum 	 → 	 Tum
# ad 	 → 	 ad
# solennes 	 → 	 solennes
# pe 	 → 	 pe
# uuꝶ 	 → 	 uua
# populique 	 → 	 populique
# conventus 	 → 	 conventus
# frequentissimos 	 → 	 frequentissimus
# in 	 → 	 in
# quibus 	 → 	 quibus
# vulgus 	 → 	 vulgus
# putat 	 → 	 putat
# esse 	 → 	 esse
# res 	 → 	 res
# maxime 	 → 	 maxime
# spoctatu 	 → 	 spectat
# dignas 	 → 	 dignas
# sisdem 	 → 	 isdem
# licet 	 → 	 licet
# accedere 	 → 	 accedere
# Tyranni 	 → 	 Tyranni
# porro 	 → 	 porro
# non 	 → 	 non
# multum 	 → 	 multum
# indulgent 	 → 	 indulgent
# spectaculis 	 → 	 spectaculis
# raroque 	 → 	 raroque
# intersunt 	 → 	 intersunt
# eo 	 → 	 eo
# quod 	 → 	 quod
# ipsis 	 → 	 ipsis
# eo 	 → 	 eo
# proficisci 	 → 	 proficisci
# tutum 	 → 	 tutum
# non 	 → 	 non
# est 	 → 	 est
# ubi 	 → 	 ubi
# non 	 → 	 non
# sint 	 → 	 sint
# futuri 	 → 	 futuri
# superiores 	 → 	 superiores
# iis 	 → 	 iis
# quiadsunt 	 → 	 quiadsunt
# Nec 	 → 	 Nec
# quae 	 → 	 quae
# domi 	 → 	 domi
# possident 	 → 	 possident
# in 	 → 	 in
# tuto 	 → 	 tuto
# sunt 	 → 	 sunt
# ut 	 → 	 ut
# his 	 → 	 his
# apud 	 → 	 apud
# alios 	 → 	 alios
# depositis 	 → 	 depositis
# liceat 	 → 	 liceat
# abesse 	 → 	 abesse
# peregre 	 → 	 peregre
# Metuendum 	 → 	 Metuendum
# enim 	 → 	 enim
# est 	 → 	 est
# ne 	 → 	 ne
# u 	 → 	 u
# et 	 → 	 et
# Principatu 	 → 	 Principatu
# excutiantur 	 → 	 excutiuntur
# et 	 → 	 et
# facultatem 	 → 	 facultatem
# amittant 	 → 	 amittant
# ulciscendi 	 → 	 ulciscendi
# eos 	 → 	 eos
# a 	 → 	 ad
# quibus 	 → 	 quibus
# laesi 	 → 	 laesi
# sunt 	 → 	 sunt
# Proinde 	 → 	 Proinde
# forsitan 	 → 	 forsitan
# dices 	 → 	 dices
# tu 	 → 	 tu
# quidem 	 → 	 quidem
# Ista 	 → 	 Ista
# nimirum 	 → 	 nimirum
# spectacula 	 → 	 spectacula
# veniunt 	 → 	 veniunt
# ad 	 → 	 ad
# Tyrannos 	 → 	 Tyrannos
# etiamsi 	 → 	 etiamsi
# domi 	 → 	 domi
# maneant 	 → 	 maneant
# Veniunt 	 → 	 Veniunt
# per 	 → 	 per
# Jovem 	 → 	 Jovem
# Simonides 	 → 	 Simonides
# at 	 → 	 at
# non 	 → 	 non
# solum 	 → 	 solum
# pauca 	 → 	 pauca
# e 	 → 	 e
# multis 	 → 	 multis
# verum 	 → 	 verum
# etiam 	 → 	 etiam
# quum 	 → 	 quum
# ejusmodi 	 → 	 ejusmodi
# sint 	 → 	 sint
# adeo 	 → 	 adeo
# care 	 → 	 care
# emenda 	 → 	 emenda
# Tyrannis 	 → 	 Tyrannis
# ut 	 → 	 ut
# qui 	 → 	 qui
# vel 	 → 	 vel
# qualecumque 	 → 	 qualecumque
# spectaculum 	 → 	 spectaculum
# ediderint 	 → 	 ediderint
# postulent 	 → 	 postulent
# longe 	 → 	 longe
# majoribus 	 → 	 majoribus
# praemiis 	 → 	 praemiis
# brevi 	 → 	 brevi
# tempore 	 → 	 tempore
# acceptis 	 → 	 acceptis
# a 	 → 	 ad
# Rege 	 → 	 Rege
# discedere 	 → 	 discedere
# quam 	 → 	 quam
# quae 	 → 	 quae
# per 	 → 	 per
# omnem 	 → 	 omnem
# vitam 	 → 	 vitam
# a 	 → 	 ad
# caeteris 	 → 	 caeteris
# omnibus 	 → 	 omnibus
# acquirunt 	 → 	 acquirunt
# Tum 	 → 	 Tum
# Simonides 	 → 	 Simonides
# Verum 	 → 	 Verum
# inquit 	 → 	 inquit
# quamquam 	 → 	 quamquam
# inferiores 	 → 	 inferiores
# estis 	 → 	 estis
# in 	 → 	 in
# spectaculis 	 → 	 spectaculis
# tamen 	 → 	 tamen
# potiores 	 → 	 potiores
# fertis 	 → 	 fertis
# in 	 → 	 in
# his 	 → 	 his
# quae 	 → 	 quae
# delectant 	 → 	 delectant
# aureis 	 → 	 aureis
# quandoquidem 	 → 	 quandoquidem
# Iaudum 	 → 	 laudum
# quibus 	 → 	 quibus
# nihil 	 → 	 nihil
# estauditu 	 → 	 estauditu
# jucundius 	 → 	 jucundius
# nullaumquam 	 → 	 nullaumquam
# vobis 	 → 	 vobis
# est 	 → 	 est
# penuria 	 → 	 penuria
# Quotquot 	 → 	 Quotquot
# enim 	 → 	 enim
# sunt 	 → 	 sunt
# vobiscum 	 → 	 vobiscum
# agunt 	 → 	 agunt
# consuetudinem 	 → 	 consuetudinem
# omnia 	 → 	 omnia
# quaecumque 	 → 	 quaecumque
# vel 	 → 	 vel
# dicitis 	 → 	 dicitis
# vel 	 → 	 vel
# facitis 	 → 	 facitis
# laudant 	 → 	 laudant
# Caeterum 	 → 	 Caeterum
# a 	 → 	 ad
# conviciis 	 → 	 conviciis
# quibus 	 → 	 quibus
# nihil 	 → 	 nihil
# est 	 → 	 est
# auditu 	 → 	 auditu
# insuavius 	 → 	 insuavis
# liberae 	 → 	 liberae
# sunt 	 → 	 sunt
# aures 	 → 	 aures
# vestrae 	 → 	 vestrae
# Nullus 	 → 	 Nullus
# enim 	 → 	 enim
# vult 	 → 	 vult
# Tyrannum 	 → 	 Tyrannum
# coram 	 → 	 coram
# et 	 → 	 et
# in 	 → 	 in
# os 	 → 	 os
# vituperare 	 → 	 vituperare
# Tum 	 → 	 Tum
# Hieron 	 → 	 Hieron
# Et 	 → 	 Et
# quid 	 → 	 quid
# inquit 	 → 	 inquit
# voluptatis 	 → 	 voluptatis
# existimas 	 → 	 existimas
# adferre 	 → 	 adferre
# eos 	 → 	 eos
# qui 	 → 	 qui
# non 	 → 	 non
# maledicunt 	 → 	 maledicunt
# ubi 	 → 	 ubi
# quis 	 → 	 quis
# evidenter 	 → 	 evidenter
# perspicit 	 → 	 perspicit
# quod 	 → 	 quod
# hi 	 → 	 hi
# omnes 	 → 	 omnes
# dum 	 → 	 dum
# tacent 	 → 	 tacent
# male 	 → 	 male
# volunt 	 → 	 volunt
# Tyranno 	 → 	 Tyranno
# Aut 	 → 	 Aut
# quid 	 → 	 quid
# voluptatis 	 → 	 voluptatis
# adferre 	 → 	 adferre
# putas 	 → 	 putas
# eos 	 → 	 eos
# qui 	 → 	 qui
# laudant 	 → 	 laudant
# quum 	 → 	 quum
# suspecti 	 → 	 suspecti
# sint 	 → 	 sint
# quod 	 → 	 quod
# adsentandi 	 → 	 adsentandi
# gratia 	 → 	 gratia
# laudent 	 → 	 laudent
# non 	 → 	 non
# ex 	 → 	 ex
# animo 	 → 	 animo
# At 	 → 	 At
# Simonides 	 → 	 Simonides
# In 	 → 	 In
# hoc 	 → 	 hoc
# quidem 	 → 	 quidem
# per 	 → 	 per
# Jovem 	 → 	 Jovem
# inquit 	 → 	 inquit
# tibi 	 → 	 tibi
# prorsus 	 → 	 prorsus
# adsentior 	 → 	 adsentior
# Hieron 	 → 	 Hieron
# Laudes 	 → 	 Laudes
# allatas 	 → 	 allatas
# ab 	 → 	 ab
# his 	 → 	 his
# qui 	 → 	 qui
# quam 	 → 	 quam
# maxime 	 → 	 maxime
# liberi 	 → 	 liberi
# sunt 	 → 	 sunt
# esse 	 → 	 esse
# multo 	 → 	 multo
# jucundisimas 	 → 	 iucundissimas
# Verum 	 → 	 Verum
# tamen 	 → 	 tamen
# illud 	 → 	 illud
# plane 	 → 	 plane
# vides 	 → 	 vides
# te 	 → 	 te
# jam 	 → 	 jam
# nulli 	 → 	 nulli
# mortallum 	 → 	 mortalium
# persuasurum 	 → 	 persuasurum
# esse 	 → 	 esse
# quin 	 → 	 quin
# in 	 → 	 in
# his 	 → 	 his
# quibus 	 → 	 quibus
# homines 	 → 	 homines
# vos 	 → 	 vos
# longe 	 → 	 longe
# plus 	 → 	 plus
# voluptatis 	 → 	 voluptatis
# capiatis 	 → 	 capiatis
# Nec 	 → 	 Nec
# istud 	 → 	 istud
# inquit 	 → 	 inquit
# me 	 → 	 me
# fugit 	 → 	 fugit
# ὃ 	 → 	 ὃ
# Simonides 	 → 	 Simonides
# ita 	 → 	 ita
# plerisque 	 → 	 plerisque
# videri 	 → 	 videri
# nos 	 → 	 nos
# tum 	 → 	 tum
# edere 	 → 	 edere
# tum 	 → 	 tum
# bibere 	 → 	 bibere
# suavius 	 → 	 suavius
# hominibus 	 → 	 hominibus
# privatis 	 → 	 privatis
# eo 	 → 	 eo
# quod 	 → 	 quod
# ipsi 	 → 	 ipsi
# quoque 	 → 	 quoque
# sibi 	 → 	 sibi
# videntur 	 → 	 videntur
# jucundius 	 → 	 jucundius
# coenaturi 	 → 	 cenaturi
# coe 	 → 	 cor
# nam 	 → 	 nam
# quae 	 → 	 quae
# nobis 	 → 	 nobis
# adponitur 	 → 	 adponitur
# quam 	 → 	 quam
# ecam 	 → 	 eam
# quae 	 → 	 quae
# ipsis 	 → 	 ipsis
# adponitur 	 → 	 adponitur
# Non 	 → 	 Non
# enim 	 → 	 enim
# ipsa 	 → 	 ipsa
# res 	 → 	 res
# voluptatem 	 → 	 voluptatem
# adfert 	 → 	 adfert
# Sed 	 → 	 Sed
# hoc 	 → 	 hoc
# illos 	 → 	 illos
# delectat 	 → 	 delectat
# quod 	 → 	 quod
# apparatus 	 → 	 apparatus
# superat 	 → 	 superat
# ea 	 → 	 ea
# quibus 	 → 	 quibus
# adsueverunt 	 → 	 adseverant
# Eoque 	 → 	 Eoque
# cuncti 	 → 	 cuncti
# mortales 	 → 	 mortales
# cupide 	 → 	 cupide
# exspectant 	 → 	 exspectant
# dies 	 → 	 dies
# festos 	 → 	 festos
# exceptis 	 → 	 exceptis
# Tyrannis 	 → 	 Tyrannis
# semper 	 → 	 semper
# enim 	 → 	 enim
# his 	 → 	 his
# splendidus 	 → 	 splendidus
# estapparatus 	 → 	 estapparatus
# nec 	 → 	 nec
# ullam 	 → 	 ullam
# illorum 	 → 	 illorum
# mensae 	 → 	 mensae
# diebus 	 → 	 diebus
# festis 	 → 	 festis
# accipiunt 	 → 	 accipiunt
# accessionem 	 → 	 accessionem
# Primum 	 → 	 Primum
# igitur 	 → 	 igitur
# quod 	 → 	 quod
# ad 	 → 	 ad
# hanc 	 → 	 hanc
# voluptatem 	 → 	 voluptatem
# quam 	 → 	 quam
# adfert 	 → 	 adfert
# spes 	 → 	 spes
# attinet 	 → 	 attinet
# deteriore 	 → 	 deteriore
# conditione 	 → 	 conditione
# sunt 	 → 	 sunt
# Reges 	 → 	 Reges
# quam 	 → 	 quam
# privati 	 → 	 privati
# Praeterea 	 → 	 Praeterea
# inquit 	 → 	 inquit
# illud 	 → 	 illud
# sat 	 → 	 sat
# scio 	 → 	 scio
# tu 	 → 	 tu
# quoque 	 → 	 quoque
# vel 	 → 	 vel
# experientia 	 → 	 experientia
# compertum 	 → 	 compertum
# habes 	 → 	 habes
# quo 	 → 	 quo
# cuique 	 → 	 cuique
# plura 	 → 	 plura
# quam 	 → 	 quam
# sat 	 → 	 sat
# est 	 → 	 est
# ac 	 → 	 ac
# redundantia 	 → 	 redundantia
# apponuntur 	 → 	 apponuntur
# tanto 	 → 	 tanto
# citius 	 → 	 citius
# edendi 	 → 	 edendi
# satietatem 	 → 	 satietatem
# oboriri 	 → 	 oriri
# Ita 	 → 	 Ita
# fit 	 → 	 fit
# ut 	 → 	 ut
# ipso 	 → 	 ipso
# quoque 	 → 	 quoque
# tempore 	 → 	 tempore
# quo 	 → 	 quo
# cibum 	 → 	 cibum
# capis 	 → 	 capis
# si 	 → 	 si
# multa 	 → 	 multa
# apponantur 	 → 	 apponatur
# deterius 	 → 	 deterius
# habeas 	 → 	 habeas
# quam 	 → 	 quam
# ii 	 → 	 ii
# qui 	 → 	 qui
# moderato 	 → 	 moderato
# sunt 	 → 	 sunt
# victu 	 → 	 victu
# Atqui 	 → 	 Atqui
# per 	 → 	 per
# Jovem 	 → 	 Jovem
# inquit 	 → 	 inquit
# Simonides 	 → 	 Simonides
# tantisper 	 → 	 tantisper
# dum 	 → 	 dum
# appetit 	 → 	 appetit
# animus 	 → 	 animus
# multo 	 → 	 multo
# plus 	 → 	 plus
# habent 	 → 	 habent
# voluptatis 	 → 	 voluptatis
# qui 	 → 	 qui
# splendido 	 → 	 splendido
# Vivunt 	 → 	 Vivunt
# apparatu 	 → 	 apparatu
# quam 	 → 	 quam
# hi 	 → 	 hi
# quibus 	 → 	 quibus
# tenuis 	 → 	 tenuis
# victus 	 → 	 victus
# apponitur 	 → 	 apponitur
# Ad 	 → 	 Ad
# haec 	 → 	 haec
# Hieron 	 → 	 Hieron
# Itane 	 → 	 Itane
# inquit 	 → 	 inquit
# o 	 → 	 o
# Simonides 	 → 	 Simonides
# putas 	 → 	 putas
# eum 	 → 	 eum
# qui 	 → 	 qui
# re 	 → 	 re
# quapiam 	 → 	 quapiam
# delectatur 	 → 	 delectatur
# hunc 	 → 	 hunc
# protinus 	 → 	 protinus
# maxime 	 → 	 maxime
# adfici 	 → 	 adfici
# ac 	 → 	 ac
# vehementisimo 	 → 	 vehementissimo
# amore 	 → 	 amore
# teneri 	 → 	 teneri
# ejus 	 → 	 ejus
# negotii 	 → 	 negotii
# Equidem 	 → 	 Equidem
# prorsus 	 → 	 prorsus
# arbitror 	 → 	 arbitror
# inquit 	 → 	 inquit
# Nempe 	 → 	 Nempe
# igitur 	 → 	 igitur
# vides 	 → 	 vides
# Reges 	 → 	 Reges
# aliquanto 	 → 	 aliquanto
# libentius 	 → 	 libentius
# ad 	 → 	 ad
# suos 	 → 	 suos
# apparatus 	 → 	 apparatus
# ire 	 → 	 ire
# an 	 → 	 an
# homines 	 → 	 homines
# privatos 	 → 	 privatos
# ad 	 → 	 ad
# suos 	 → 	 suos
# Nequaquam 	 → 	 Nequaquam
# per 	 → 	 per
# sovem 	 → 	 solem
# inquit 	 → 	 inquit
# non 	 → 	 non
# sane 	 → 	 sane
# video 	 → 	 video
# sed 	 → 	 sed
# illubentius 	 → 	 lubentius
# ut 	 → 	 ut
# vulgo 	 → 	 vulgo
# quidem 	 → 	 quidem
# videri 	 → 	 videri
# possit 	 → 	 possit
# Tum 	 → 	 Tum
# Hieron 	 → 	 Hieron
# Quid 	 → 	 Quid
# inquit 	 → 	 inquit
# num 	 → 	 num
# ista 	 → 	 ista
# multo 	 → 	 multo
# studio 	 → 	 studio
# arteque 	 → 	 arteque
# confecta 	 → 	 confecta
# considerasti 	 → 	 consideranti
# quae 	 → 	 quae
# Regibus 	 → 	 Regibus
# adponuntur 	 → 	 adponuntur
# acria 	 → 	 acria
# amara 	 → 	 amara
# austeraque 	 → 	 alteraque
# et 	 → 	 et
# his 	 → 	 his
# germana 	 → 	 germana
# Prorsus 	 → 	 Prorsus
# inquit 	 → 	 inquit
# Simonides 	 → 	 Simonides
# consideravi 	 → 	 consideravi
# Planeque 	 → 	 Planeque
# mihi 	 → 	 mihi
# quidem 	 → 	 quidem
# ista 	 → 	 ista
# videntur 	 → 	 videntur
# esse 	 → 	 esse
# praeter 	 → 	 praeter
# naturam 	 → 	 naturam
# hominibus 	 → 	 hominibus
# adscita 	 → 	 adscita
# Quid 	 → 	 Quid
# igitur 	 → 	 igitur
# inquit 	 → 	 inquit
# Hieron 	 → 	 Hieron
# aliud 	 → 	 aliud
# existimas 	 → 	 existimas
# hoc 	 → 	 hoc
# genus 	 → 	 genus
# epulas 	 → 	 epulas
# esse 	 → 	 esse
# nisi 	 → 	 nisi
# mollis 	 → 	 mollis
# ac 	 → 	 ac
# deliciis 	 → 	 deliciis
# efsoe 	 → 	 esse
# minati 	 → 	 minati
# animi 	 → 	 animi
# concupiscentias 	 → 	 concupiscentias
# Siquidem 	 → 	 Siquidem
# ego 	 → 	 ego
# sane 	 → 	 sane
# probe 	 → 	 probe
# novi 	 → 	 novi
# quin 	 → 	 quin
# nosti 	 → 	 nosti
# tu 	 → 	 tu
# quoque 	 → 	 quoque
# forsitan 	 → 	 forsitan
# quod 	 → 	 quod
# qui 	 → 	 qui
# cupide 	 → 	 cupide
# vescuntur 	 → 	 vescuntur
# nihil 	 → 	 nihil
# opus 	 → 	 opus
# habent 	 → 	 habent
# istis 	 → 	 istis
# arte 	 → 	 arte
# additis 	 → 	 additis
# condituris 	 → 	 condituris
# Quin 	 → 	 Quin
# etiam 	 → 	 etiam
# vobis 	 → 	 vobis
# ex 	 → 	 ex
# odoribus 	 → 	 odoribus
# inquit 	 → 	 inquit
# Simonides 	 → 	 Simonides
# istis 	 → 	 istis
# pretiosis 	 → 	 pretiosis
# quibus 	 → 	 quibus
# ungimigimini 	 → 	 ungimigimini
# arbitror 	 → 	 arbitror
# eos 	 → 	 eos
# plus 	 → 	 plus
# boni 	 → 	 boni
# capere 	 → 	 capere
# qui 	 → 	 qui
# sunt 	 → 	 sunt
# familiares 	 → 	 familiares
# quam 	 → 	 quam
# vos 	 → 	 vos
# ipsos 	 → 	 ipsos
# quandoquidem 	 → 	 quandoquidem
# et 	 → 	 et
# ingratos 	 → 	 ingratos
# odores 	 → 	 odores
# non 	 → 	 non
# sentit 	 → 	 sentit
# is 	 → 	 is
# qui 	 → 	 qui
# se 	 → 	 se
# illis 	 → 	 illis
# explevit 	 → 	 explevit
# sed 	 → 	 sed
# hi 	 → 	 hi
# potius 	 → 	 potius
# qui 	 → 	 qui
# ad 	 → 	 ad
# eum 	 → 	 eum
# qui 	 → 	 qui
# devoravit 	 → 	 devoravit
# accedunt 	 → 	 accedunt
# Itidem 	 → 	 Itidem
# inquit 	 → 	 inquit
# Hieron 	 → 	 Hieron
# usu 	 → 	 usu
# venit 	 → 	 venit
# in 	 → 	 in
# cibis 	 → 	 cibis
# Cui 	 → 	 Cui
# perpetuo 	 → 	 perpetuo
# suppetit 	 → 	 suppetit
# omne 	 → 	 omne
# genus 	 → 	 genus
# epularum 	 → 	 epularum
# nihil 	 → 	 nihil
# illorum 	 → 	 illorum
# sumit 	 → 	 sumit
# cum 	 → 	 cum
# appetentia 	 → 	 appetentis
# Verum 	 → 	 Verum
# cui 	 → 	 cui
# quid 	 → 	 quid
# raro 	 → 	 raro
# contingit 	 → 	 contingit
# is 	 → 	 is
# demum 	 → 	 demum
# est 	 → 	 est
# qui 	 → 	 qui
# cum 	 → 	 cum
# voluptate 	 → 	 voluptate
# satiatur 	 → 	 satiatur
# si 	 → 	 si
# quidilIi 	 → 	 quidilIi
# objiciatur 	 → 	 obiciatur
# Solae 	 → 	 Solae
# igitur 	 → 	 igitur
# inquit 	 → 	 inquit
# Simonides 	 → 	 Simonides
# Venereae 	 → 	 veneriae
# rei 	 → 	 rei
# delectationes 	 → 	 delectationes
# veniunt 	 → 	 veniunt
# in 	 → 	 in
# periculum 	 → 	 periculum
# ne 	 → 	 ne
# videantur 	 → 	 videantur
# regni 	 → 	 regni
# cupiditatem 	 → 	 cupiditatem
# adferre 	 → 	 adferre
# Hic 	 → 	 Hic
# enim 	 → 	 enim
# solis 	 → 	 solis
# vobis 	 → 	 vobis
# licet 	 → 	 licet
# ut 	 → 	 ut
# quidque 	 → 	 quidque
# visum 	 → 	 visum
# fuerit 	 → 	 fuerit
# pulcerrimum 	 → 	 pulcerrimum
# cum 	 → 	 cum
# eo 	 → 	 eo
# congredi 	 → 	 congredi
# Nunc 	 → 	 Nunc
# demum 	 → 	 demum
# inquit 	 → 	 inquit
# Hieron 	 → 	 Hieron
# commemorasti 	 → 	 commemorati
# in 	 → 	 in
# quo 	 → 	 quo
# citra 	 → 	 citra
# controversiam 	 → 	 controversiam
# inferiores 	 → 	 inferiores
# sumus 	 → 	 sumus
# hominibus 	 → 	 hominibus
# privatis 	 → 	 privatis
# Principio 	 → 	 Principio
# namque 	 → 	 namque
# pulcerrimum 	 → 	 pulcerrimum
# esse 	 → 	 esse
# videtur 	 → 	 videtur
# uxorem 	 → 	 uxorem
# ducere 	 → 	 ducere
# ex 	 → 	 ex
# his 	 → 	 his
# qui 	 → 	 qui
# tum 	 → 	 tum
# opibus 	 → 	 opibus
# tum 	 → 	 tum
# potentia 	 → 	 potentia
# praecellunt 	 → 	 praecellunt
# eaque 	 → 	 eaque
# res 	 → 	 res
# puratur 	 → 	 putatur
# adjungere 	 → 	 adjungere
# cum 	 → 	 cum
# voluptate 	 → 	 voluptate
# dignitatis 	 → 	 dignitatis
# nonnihil 	 → 	 nonnihil
# ci 	 → 	 ci
# qui 	 → 	 qui
# duxit 	 → 	 duxit
# Proximum 	 → 	 Proximum
# autem 	 → 	 autem
# est 	 → 	 est
# ex 	 → 	 ex
# paribus 	 → 	 paribus
# uxorem 	 → 	 uxorem
# adsciscere 	 → 	 adsciscere
# Caeterum 	 → 	 Caeterum
# cum 	 → 	 cum
# inferioribus 	 → 	 inferioribus
# contractum 	 → 	 contractum
# matrimonium 	 → 	 matrimonium
# prorsus 	 → 	 prorsus
# contemtum 	 → 	 contemtum
# et 	 → 	 et
# injucundum 	 → 	 iniucundum
# habetur 	 → 	 habetur
# At 	 → 	 At
# Regi 	 → 	 Regi
# nisi 	 → 	 nisi
# peregrinam 	 → 	 peregrinam
# ducat 	 → 	 ducat
# ex 	 → 	 ex
# inferioribus 	 → 	 inferioribus
# ducat 	 → 	 ducat
# necesse 	 → 	 necesse
# est 	 → 	 est
# Unde 	 → 	 Unde
# fit 	 → 	 fit
# ut 	 → 	 ut
# non 	 → 	 non
# admodum 	 → 	 admodum
# ad 	 → 	 ad
# eum 	 → 	 eum
# perveniat 	 → 	 perveniat
# illud 	 → 	 illud
# amabile 	 → 	 amabile
# vigorque 	 → 	 vigore
# caritatis 	 → 	 caritatis
# quae 	 → 	 quae
# inter 	 → 	 inter
# ejusdem 	 → 	 ejusdem
# civitatis 	 → 	 civitatis
# conjuges 	 → 	 conjuges
# intercedit 	 → 	 intercedit
# Jam 	 → 	 Jam
# vero 	 → 	 vero
# et 	 → 	 et
# coli 	 → 	 coli
# captarique 	 → 	 caeterique
# a 	 → 	 ad
# foeminis 	 → 	 foeminis
# maxime 	 → 	 maxime
# elatis 	 → 	 elatis
# plurimum 	 → 	 plurimum
# habet 	 → 	 habet
# voluptatis 	 → 	 voluptatis
# Caeterum 	 → 	 Caeterum
# quae 	 → 	 quae
# veniunt 	 → 	 veniunt
# abancillis 	 → 	 ancillis
# culturae 	 → 	 culturae
# quum 	 → 	 quum
# adsunt 	 → 	 adsunt
# nihilexplent 	 → 	 nihilexplent
# animum 	 → 	 animum
# Sindesint 	 → 	 Sindesint
# alicubi 	 → 	 alicubi
# graves 	 → 	 graves
# tum 	 → 	 tum
# iras 	 → 	 iras
# tum 	 → 	 tum
# molestias 	 → 	 molestias
# gignunt 	 → 	 gignunt
# in 	 → 	 in
# nobis 	 → 	 nobis
# Porro 	 → 	 Porro
# in 	 → 	 in
# puellarum 	 → 	 puellarum
# amoribus 	 → 	 amoribus
# multo 	 → 	 multo
# etiam 	 → 	 etiam
# minus 	 → 	 minus
# habet 	 → 	 habet
# voluptatum 	 → 	 voluptatum
# Tyrannus 	 → 	 Tyrannus
# quam 	 → 	 quam
# in 	 → 	 in
# uxoribus 	 → 	 uxoribus
# quae 	 → 	 quae
# ducuntur 	 → 	 ducuntur
# gignendae 	 → 	 gignenda
# proli 	 → 	 proli
# Nam 	 → 	 Nam
# quod 	 → 	 quod
# Venerei 	 → 	 venerem
# congressus 	 → 	 congressus
# si 	 → 	 si
# adsit 	 → 	 adsit
# amor 	 → 	 amor
# plurimum 	 → 	 plurimum
# adferant 	 → 	 adferant
# voluptatis 	 → 	 voluptatis
# profecto 	 → 	 profecto
# perspicuum 	 → 	 perspicuum
# est 	 → 	 est
# nobis 	 → 	 nobis
# omnibus 	 → 	 omnibus
# At 	 → 	 At
# rursus 	 → 	 rursus
# amor 	 → 	 amor
# cuivis 	 → 	 cuivis
# mavult 	 → 	 mavult
# innasci 	 → 	 innasci
# quam 	 → 	 quam
# Tyranno 	 → 	 Tyranno
# Neque 	 → 	 Neque
# enim 	 → 	 enim
# amor 	 → 	 amor
# appetere 	 → 	 appetere
# gaudet 	 → 	 gaudet
# ea 	 → 	 ea
# quae 	 → 	 quae
# in 	 → 	 in
# promptu 	 → 	 promptu
# sunt 	 → 	 sunt
# sed 	 → 	 sed
# ea 	 → 	 ea
# quae 	 → 	 quae
# sperantur 	 → 	 sperantur
# Proinde 	 → 	 Proinde
# non 	 → 	 non
# aliter 	 → 	 aliter
# quam 	 → 	 quam
# si 	 → 	 si
# qui 	 → 	 qui
# numquam 	 → 	 numquam
# expertus 	 → 	 expertus
# est 	 → 	 est
# sitim 	 → 	 sitim
# potum 	 → 	 potum
# nanciscatur 	 → 	 nanciscatur
# itidem 	 → 	 itidem
# qui 	 → 	 qui
# est 	 → 	 est
# expers 	 → 	 expers
# amoris 	 → 	 amoris
# expers 	 → 	 expers
# est 	 → 	 est
# jucundissimae 	 → 	 jucundissime
# Veneris 	 → 	 Veneris
# Hunc 	 → 	 Hunc
# igitur 	 → 	 igitur
# in 	 → 	 in
# modum 	 → 	 modum
# loquutus 	 → 	 loquutus
# est 	 → 	 est
# Hieron 	 → 	 Hieron
# Simonides 	 → 	 Simonides
# vero 	 → 	 vero
# arridens 	 → 	 arridens
# Quid 	 → 	 Quid
# ais 	 → 	 ais
# inquit 	 → 	 inquit
# Hieron 	 → 	 Hieron
# Negas 	 → 	 Negas
# puellarum 	 → 	 puellarum
# amores 	 → 	 amores
# inseri 	 → 	 inseri
# Regumanimis 	 → 	 Regumanimis
# Quomodo 	 → 	 Quomodo
# igitur 	 → 	 igitur
# inquis 	 → 	 inquis
# amas 	 → 	 amas
# Dailocham 	 → 	 Dailocham
# cui 	 → 	 cui
# cognomen 	 → 	 cognomen
# est 	 → 	 est
# pulcerrimae 	 → 	 pulcherrimae
# Quoniam 	 → 	 Quoniam
# per 	 → 	 per
# Jovem 	 → 	 Jovem
# inquit 	 → 	 inquit
# o 	 → 	 o
# Simonides 	 → 	 Simonides
# non 	 → 	 non
# hoc 	 → 	 hoc
# amo 	 → 	 amo
# quod 	 → 	 quod
# ab 	 → 	 ab
# ea 	 → 	 ea
# consequi 	 → 	 consequi
# videtur 	 → 	 videtur
# esse 	 → 	 esse
# proclive 	 → 	 proclive
# verum 	 → 	 verum
# ideo 	 → 	 ideo
# juvat 	 → 	 juvat
# quod 	 → 	 quod
# minime 	 → 	 minime
# Regem 	 → 	 Regem
# deceat 	 → 	 deceat
# hoc 	 → 	 hoc
# facere 	 → 	 facere
# Nam 	 → 	 Nam
# ego 	 → 	 ego
# quidem 	 → 	 quidem
# diligo 	 → 	 diligo
# Dailocham 	 → 	 Dailocham
# ob 	 → 	 ob
# quaecumque 	 → 	 quaecumque
# sunt 	 → 	 sunt
# illa 	 → 	 illa
# quae 	 → 	 quae
# fortassis 	 → 	 fortassis
# natura 	 → 	 natura
# hominis 	 → 	 hominis
# cogit 	 → 	 cogit
# a 	 → 	 ad
# formosis 	 → 	 formosis
# petere 	 → 	 petere
# Caeterum 	 → 	 Caeterum
# his 	 → 	 his
# potiri 	 → 	 potiri
# quae 	 → 	 quae
# amo 	 → 	 amo
# ut 	 → 	 ut
# cum 	 → 	 cum
# mutua 	 → 	 mutua
# benevolentia 	 → 	 benevolentia
# et 	 → 	 et
# a 	 → 	 ad
# volente 	 → 	 volente
# contingat 	 → 	 contingat
# vehementer 	 → 	 vehementer
# opto 	 → 	 opto
# Ut 	 → 	 Ut
# autem 	 → 	 autem
# vi 	 → 	 vi
# ab 	 → 	 ab
# illa 	 → 	 illa
# sumam 	 → 	 sumam
# minus 	 → 	 minus
# mihi 	 → 	 mihi
# videor 	 → 	 videor
# concupiscere 	 → 	 concupiscere
# quam 	 → 	 quam
# concuisco 	 → 	 concupisco
# mihi 	 → 	 mihi
# ipsi 	 → 	 ipsi
# mali 	 → 	 mali
# quidpiam 	 → 	 quidpiam
# facere 	 → 	 facere
# Nam 	 → 	 Nam
# ab 	 → 	 ab
# invitis 	 → 	 invitis
# hostialiquid 	 → 	 hostialiquid
# sumere 	 → 	 sumere
# rem 	 → 	 rem
# equidem 	 → 	 equidem
# arbitror 	 → 	 arbitror
# omnium 	 → 	 omnium
# jucundissimam 	 → 	 iucundissimam
# Sed 	 → 	 Sed
# a 	 → 	 ad
# puellis 	 → 	 puellis
# volentibus 	 → 	 volentibus
# gratia 	 → 	 gratia
# ut 	 → 	 ut
# opinor 	 → 	 opinor
# jucundissima 	 → 	 iucundissima
# venit 	 → 	 venit
# Protinus 	 → 	 Protinus
# enim 	 → 	 enim
# ipse 	 → 	 ipse
# mutuus 	 → 	 mutuus
# redamantis 	 → 	 adamantis
# adspectus 	 → 	 adspectus
# jucundus 	 → 	 jucundus
# est 	 → 	 est
# jucundae 	 → 	 jucundae
# percontationes 	 → 	 percontatione
# jucundae 	 → 	 jucundae
# responsiones 	 → 	 responsiones
# jucundissimae 	 → 	 jucundissime
# vero 	 → 	 vero
# et 	 → 	 et
# in 	 → 	 in
# primis 	 → 	 primis
# Venereae 	 → 	 veneriae
# tum 	 → 	 tum
# lites 	 → 	 lites
# tum 	 → 	 tum
# contentiones 	 → 	 contentiones
# At 	 → 	 At
# invitis 	 → 	 invitis
# puellis 	 → 	 puellis
# frui 	 → 	 frui
# latrocinio 	 → 	 latrocinio
# inquit 	 → 	 inquit
# mihi 	 → 	 mihi
# similius 	 → 	 similius
# videtur 	 → 	 videtur
# quam 	 → 	 quam
# voluptati 	 → 	 voluptati
# Venereae 	 → 	 veneriae
# Quamquam 	 → 	 Quamquam
# praedoni 	 → 	 praedoni
# nonnihil 	 → 	 nonnihil
# adfert 	 → 	 adfert
# voluptatis 	 → 	 voluptatis
# partim 	 → 	 partim
# lucrum 	 → 	 lucrum
# partim 	 → 	 partim
# quod 	 → 	 quod
# urit 	 → 	 urit
# inimicum 	 → 	 inimicum
# At 	 → 	 At
# quam 	 → 	 quam
# quis 	 → 	 quis
# amat 	 → 	 amat
# ejus 	 → 	 ejus
# cruciatu 	 → 	 cruciatu
# gaudere 	 → 	 gaudere
# 8et 	 → 	 et
# amantem 	 → 	 amantem
# odisse 	 → 	 odisse
# et 	 → 	 et
# attingere 	 → 	 attingere
# moleste 	 → 	 moleste
# ferentem 	 → 	 ferentem
# an 	 → 	 an
# non 	 → 	 non
# hoc 	 → 	 hoc
# grave 	 → 	 grave
# ac 	 → 	 ac
# miserandum 	 → 	 miserandum
# st 	 → 	 st
# malum 	 → 	 malum
# Etenim 	 → 	 Etenim
# homini 	 → 	 homini
# privato 	 → 	 privato
# protinus 	 → 	 protinus
# argumentum 	 → 	 argumentum
# est 	 → 	 est
# mutui 	 → 	 mutui
# amoris 	 → 	 amoris
# ubi 	 → 	 ubi
# quae 	 → 	 quae
# diligitur 	 → 	 diligitur
# praestat 	 → 	 praestat
# officii 	 → 	 officii
# quidiam 	 → 	 quidam
# eo 	 → 	 eo
# quod 	 → 	 quod
# veluti 	 → 	 veluti
# amans 	 → 	 amans
# gratificatur 	 → 	 gratificatur
# novit 	 → 	 novit
# enimilh⸗ 	 → 	 enimilh⸗
# quum 	 → 	 quum
# nulla 	 → 	 nulla
# sit 	 → 	 sit
# necessitas 	 → 	 necessitas
# ex 	 → 	 ex
# animo 	 → 	 animo
# inservire 	 → 	 inservire
# Tyranno 	 → 	 Tyranno
# vero 	 → 	 vero
# nihil 	 → 	 nihil
# est 	 → 	 est
# quod 	 → 	 quod
# fidem 	 → 	 fidem
# faciat 	 → 	 faciat
# animi 	 → 	 animi
# mutui 	 → 	 mutui
# Novimus 	 → 	 Novimus
# enim 	 → 	 enim
# eos 	 → 	 eos
# qui 	 → 	 qui
# nobis 	 → 	 nobis
# ob 	 → 	 ob
# metum 	 → 	 metum
# inserviunt 	 → 	 inserviunt
# quam 	 → 	 quam
# possunt 	 → 	 possunt
# maxime 	 → 	 maxime
# adsimulare 	 → 	 adsimulare
# amantium 	 → 	 amantium
# obsequia 	 → 	 obsequia
# Atqui 	 → 	 Atqui
# a 	 → 	 ad
# nullis 	 → 	 nullis
# plus 	 → 	 plus
# insidiarum 	 → 	 insidiarum
# Regibus 	 → 	 Regibus
# tenditur 	 → 	 tenditur
# quam 	 → 	 quam
# ab 	 → 	 ab
# his 	 → 	 his
# qui 	 → 	 qui
# se 	 → 	 se
# simuIant 	 → 	 simulant
# amare 	 → 	 amare
# maxime 	 → 	 maxime
# Ad 	 → 	 Ad
# haec 	 → 	 haec
# ita 	 → 	 ita
# respondit 	 → 	 respondit
# Simonides 	 → 	 Simonides
# Ista 	 → 	 Ista
# vero 	 → 	 vero
# quae 	 → 	 quae
# hactenus 	 → 	 hactenus
# narras 	 → 	 narras
# mihi 	 → 	 mihi
# videntur 	 → 	 videntur
# admodum 	 → 	 admodum
# exigui 	 → 	 exigui
# momenti 	 → 	 momenti
# Multos 	 → 	 Multos
# enim 	 → 	 enim
# video 	 → 	 video
# graves 	 → 	 graves
# probatosque 	 → 	 probatque
# viTo 	 → 	 viTo
# esse 	 → 	 esse
# qui 	 → 	 qui
# in 	 → 	 in
# hisce 	 → 	 hisce
# rebus 	 → 	 rebus
# sponte 	 → 	 sponte
# sunt 	 → 	 sunt
# aliis 	 → 	 aliis
# inferiores 	 → 	 inferiores
# quippe 	 → 	 quippe
# tuma 	 → 	 tum
# cibis 	 → 	 cibis
# tuma 	 → 	 tum
# potu 	 → 	 potu
# tum 	 → 	 tum
# ab 	 → 	 ab
# obsoniis 	 → 	 obsoniis
# ac 	 → 	 ac
# rebusadeo 	 → 	 rebusadeo
# Venereis 	 → 	 veneris
# abstinentes 	 → 	 abstinentes
# Caeterum 	 → 	 Caeterum
# in 	 → 	 in
# hoc 	 → 	 hoc
# longe 	 → 	 longe
# praecellitis 	 → 	 praecellit
# homines 	 → 	 homines
# plebejos 	 → 	 plebeios
# quod 	 → 	 quod
# ut 	 → 	 ut
# res 	 → 	 res
# magnificas 	 → 	 magnificas
# excogitatis 	 → 	 excogitatis
# ita 	 → 	 ita
# quod 	 → 	 quod
# est 	 → 	 est
# celeriter 	 → 	 celeriter
# perficitis 	 → 	 perfectis
# Ad 	 → 	 Ad
# haec 	 → 	 haec
# facultates 	 → 	 facultates
# habetis 	 → 	 habetis
# multas 	 → 	 multas
# et 	 → 	 et
# opimas 	 → 	 opimas
# possidetis 	 → 	 possidetis
# equos 	 → 	 equos
# virtute 	 → 	 virtute
# praestantes 	 → 	 praestantes
# tum 	 → 	 tum
# arma 	 → 	 arma
# insigniter 	 → 	 insigniter
# pulera 	 → 	 pulcra
# mundum 	 → 	 mundum
# eximisum 	 → 	 eximium
# uxoribus 	 → 	 uxoribus
# aedes 	 → 	 aedes
# magnificentissimas 	 → 	 magnificentissime
# easque 	 → 	 easque
# rebus 	 → 	 rebus
# pretiosissimis 	 → 	 pretiosissimis
# instructas 	 → 	 instructas
# Adde 	 → 	 Adde
# his 	 → 	 his
# quod 	 → 	 quod
# famulos 	 → 	 famulos
# tum 	 → 	 tum
# multitudine 	 → 	 multitudine
# tum 	 → 	 tum
# artibus 	 → 	 artibus
# praecelientissiimos 	 → 	 praecelientissiimos
# possidetis 	 → 	 possidetis
# Praeterea 	 → 	 Praeterea
# maxima 	 → 	 maxima
# vobis 	 → 	 vobis
# suppetit 	 → 	 suppetit
# facultas 	 → 	 facultas
# vel 	 → 	 vel
# hostibus 	 → 	 hostibus
# nocendi 	 → 	 nocendi
# vel 	 → 	 vel
# amicos 	 → 	 amicos
# juvandi 	 → 	 iuvandi
# Hisita 	 → 	 visita
# respondit 	 → 	 respondit
# Hieron 	 → 	 Hieron
# Multitudinem 	 → 	 Multitudinem
# popularem 	 → 	 popularem
# in 	 → 	 in
# judicio 	 → 	 judicio
# de 	 → 	 de
# regno 	 → 	 regno
# hallucinari 	 → 	 hallucinari
# nihil 	 → 	 nihil
# admiror 	 → 	 admiror
# Nam 	 → 	 Nam
# vulgus 	 → 	 vulgus
# hominum 	 → 	 hominum
# mihi 	 → 	 mihi
# videtur 	 → 	 videtur
# omnino 	 → 	 omnino
# ex 	 → 	 ex
# his 	 → 	 his
# quae 	 → 	 quae
# patent 	 → 	 patent
# oculis 	 → 	 oculis
# arbitrari 	 → 	 arbitrari
# alios 	 → 	 alios
# felices 	 → 	 felices
# esse 	 → 	 esse
# alios 	 → 	 alios
# contra 	 → 	 contra
# miseros 	 → 	 miseros
# Regnum 	 → 	 Regnum
# autem 	 → 	 autem
# possesiiones 	 → 	 possessiones
# quae 	 → 	 quae
# videntur 	 → 	 videntur
# plurimi 	 → 	 plurimi
# esse 	 → 	 esse
# pretii 	 → 	 pretii
# explicatas 	 → 	 explicatas
# expositasque 	 → 	 expositisque
# spectaculo 	 → 	 spectaculo
# paIam 	 → 	 palam
# omnibus 	 → 	 omnibus
# exhibet 	 → 	 exhibet
# Contra 	 → 	 Contra
# quae 	 → 	 quae
# molesta 	 → 	 molesta
# sunt 	 → 	 sunt
# in 	 → 	 in
# animis 	 → 	 animis
# Regum 	 → 	 Regum
# tenentur 	 → 	 tenentur
# abdita 	 → 	 abdita
# ubi 	 → 	 ubi
# situm 	 → 	 situm
# estdemum 	 → 	 extremum
# hominibus 	 → 	 hominibus
# ut 	 → 	 ut
# aut 	 → 	 aut
# selices 	 → 	 felices
# sint 	 → 	 sint
# aut 	 → 	 aut
# infelices 	 → 	 infelices
# His 	 → 	 His
# igitur 	 → 	 igitur
# in 	 → 	 in
# rebus 	 → 	 rebus
# falli 	 → 	 falli
# quidem 	 → 	 quidem
# plebejam 	 → 	 plebeiam
# multitudinem 	 → 	 multitudinem
# ut 	 → 	 ut
# dicebam 	 → 	 dicebam
# modo 	 → 	 modo
# haud 	 → 	 haud
# admiTor 	 → 	 admiror
# vos 	 → 	 vos
# autem 	 → 	 autem
# haee 	 → 	 haec
# ignorare 	 → 	 ignorare
# qui 	 → 	 qui
# et 	 → 	 et
# mente 	 → 	 mente
# videmini 	 → 	 videmini
# perspicere 	 → 	 perspicere
# melius 	 → 	 melius
# quam 	 → 	 quam
# res 	 → 	 res
# plerasque 	 → 	 plerasque
# cernitis 	 → 	 cernitis
# oculis 	 → 	 oculis
# id 	 → 	 id
# vero 	 → 	 vero
# mihi 	 → 	 mihi
# videtur 	 → 	 videtur
# admiratione 	 → 	 admiratione
# dignum 	 → 	 dignum
# At 	 → 	 At
# ipse 	 → 	 ipse
# o 	 → 	 o
# Simonides 	 → 	 Simonides
# et 	 → 	 et
# experimentis 	 → 	 experimentis
# certo 	 → 	 certo
# cognitum 	 → 	 cognitum
# habeo 	 → 	 habeo
# et 	 → 	 et
# tibi 	 → 	 tibi
# confirmo 	 → 	 confirmo
# Tyrannos 	 → 	 Tyrannos
# maximorum 	 → 	 maximorum
# bonorum 	 → 	 bonorum
# minime 	 → 	 minime
# participes 	 → 	 participes
# esse 	 → 	 esse
# Contra 	 → 	 Contra
# maximorum 	 → 	 maximorum
# malorum 	 → 	 malorum
# illis 	 → 	 illis
# summam 	 → 	 summam
# adesse 	 → 	 adesse
# copiam 	 → 	 copiam
# Protinus 	 → 	 Protinus
# enim 	 → 	 enim
# si 	 → 	 si
# pax 	 → 	 pax
# hominibus 	 → 	 hominibus
# videtur 	 → 	 videtur
# ingens 	 → 	 ingens
# bonum 	 → 	 bonum
# hujus 	 → 	 hujus
# minima 	 → 	 minima
# pars 	 → 	 pars
# redit 	 → 	 redit
# adReges 	 → 	 adleges
# Sin 	 → 	 Sin
# pro 	 → 	 pro
# magno 	 → 	 magno
# malo 	 → 	 malo
# bellun 	 → 	 bellum
# habetur 	 → 	 habetur
# hujus 	 → 	 hujus
# multo 	 → 	 multo
# maxima 	 → 	 maxima
# pars 	 → 	 pars
# ad 	 → 	 ad
# Reges 	 → 	 Reges
# pertinet 	 → 	 pertinet
# Nam 	 → 	 Nam
# privatis 	 → 	 privatis
# nisi 	 → 	 nisi
# ipsorum 	 → 	 ipsorum
# civitas 	 → 	 civitas
# bellum 	 → 	 bellum
# commune 	 → 	 commune
# susceperit 	 → 	 susceperit
# protinus 	 → 	 protinus
# liberum 	 → 	 liberum
# est 	 → 	 est
# quocumque 	 → 	 quocumque
# voluerint 	 → 	 voluerint
# proficisci 	 → 	 proficisci
# nihil 	 → 	 nihil
# formidantibus 	 → 	 formidantibus
# ne 	 → 	 ne
# quis 	 → 	 quis
# ipsos 	 → 	 ipsos
# interficiat 	 → 	 interficiat
# Tyranni 	 → 	 Tyranni
# autem 	 → 	 autem
# omnes 	 → 	 omnes
# quoquo 	 → 	 quoquo
# se 	 → 	 se
# conferant 	 → 	 conferant
# quasi 	 → 	 quasi
# per 	 → 	 per
# hostilia 	 → 	 hostilia
# castra 	 → 	 castra
# proficiscuntur 	 → 	 proficiscuntur
# Eoque 	 → 	 Eoque
# necesse 	 → 	 necesse
# purant 	 → 	 putant
# ut 	 → 	 ut
# et 	 → 	 et
# ipsi 	 → 	 ipsi
# semper 	 → 	 semper
# sint 	 → 	 sint
# armati 	 → 	 armati
# et 	 → 	 et
# alios 	 → 	 alios
# armigeros 	 → 	 armigeros
# jugiter 	 → 	 jugiter
# secum 	 → 	 secum
# circumferant 	 → 	 circumferunt
# Praeterea 	 → 	 Praeterea
# privati 	 → 	 privati
# etiam 	 → 	 etiam
# si 	 → 	 si
# quando 	 → 	 quando
# proficiscantur 	 → 	 proficiscantur
# in 	 → 	 in
# expeditionem 	 → 	 expeditionem
# tamen 	 → 	 tamen
# simul 	 → 	 simul
# atque 	 → 	 atque
# domum 	 → 	 domum
# se 	 → 	 se
# receperint 	 → 	 receperint
# existimant 	 → 	 existimant
# sibi 	 → 	 sibi
# res 	 → 	 res
# esse 	 → 	 esse
# tutas 	 → 	 tutas
# Contra 	 → 	 Contra
# Tyranni 	 → 	 Tyranni
# quum 	 → 	 quum
# in 	 → 	 in
# suam 	 → 	 suam
# pervenerint 	 → 	 pervenerint
# civitatem 	 → 	 civitatem
# tum 	 → 	 tum
# intellighnt 	 → 	 intelligunt
# sese 	 → 	 sese
# inter 	 → 	 inter
# hostes 	 → 	 hostes
# esse 	 → 	 esse
# plurimos 	 → 	 plurimos
# Quod 	 → 	 Quod
# si 	 → 	 si
# qui 	 → 	 qui
# potentiores 	 → 	 potentiores
# alii 	 → 	 alii
# ducant 	 → 	 ducant
# exercitum 	 → 	 exercitum
# adversus 	 → 	 adversus
# civitatem 	 → 	 civitatem
# licet 	 → 	 licet
# qui 	 → 	 qui
# sunt 	 → 	 sunt
# extra 	 → 	 extra
# moenia 	 → 	 moenia
# quoniam 	 → 	 quoniam
# sunt 	 → 	 sunt
# inferiores 	 → 	 inferiores
# in 	 → 	 in
# periculo 	 → 	 periculo
# videantur 	 → 	 videantur
# esse 	 → 	 esse
# tamen 	 → 	 tamen
# simul 	 → 	 simul
# ac 	 → 	 ac
# intra 	 → 	 intra
# munitiones 	 → 	 munitiones
# se 	 → 	 se
# receperint 	 → 	 receperint
# omnes 	 → 	 omnes
# se 	 → 	 se
# credunt 	 → 	 credunt
# esse 	 → 	 esse
# in 	 → 	 in
# tuto 	 → 	 tuto
# At 	 → 	 At
# Tyrannus 	 → 	 Tyrannus
# ne 	 → 	 ne
# tum 	 → 	 tum
# quidem 	 → 	 quidem
# liber 	 → 	 liber
# esta 	 → 	 est
# periculo 	 → 	 periculo
# quum 	 → 	 quum
# in 	 → 	 in
# domus 	 → 	 domus
# suae 	 → 	 suae
# penetralia 	 → 	 penetralia
# pervenerit 	 → 	 pervenerit
# quin 	 → 	 quin
# potius 	 → 	 potius
# tum 	 → 	 tum
# maxime 	 → 	 maxime
# putat 	 → 	 putat
# esse 	 → 	 esse
# cavendum 	 → 	 cavendum
# Insuper 	 → 	 Insuper
# privatis 	 → 	 privatis
# interim 	 → 	 interim
# per 	 → 	 per
# foedera 	 → 	 foedera
# interim 	 → 	 interim
# per 	 → 	 per
# pacem 	 → 	 pacem
# datura 	 → 	 datura
# bello 	 → 	 bello
# requies 	 → 	 requies
# Tyrannis 	 → 	 Tyrannis
# autem 	 → 	 autem
# numquam 	 → 	 numquam
# pax 	 → 	 pax
# est 	 → 	 est
# cum 	 → 	 cum
# his 	 → 	 his
# quos 	 → 	 quos
# imperio 	 → 	 imperio
# premunt 	 → 	 premunt
# neque 	 → 	 neque
# quisquam 	 → 	 quisquam
# Tyrannus 	 → 	 Tyrannus
# umquam 	 → 	 umquam
# foederibus 	 → 	 foederibus
# possit 	 → 	 possit
# fidere 	 → 	 fidere
# Jam 	 → 	 Jam
# bella 	 → 	 bella
# partim 	 → 	 partim
# sunt 	 → 	 sunt
# quae 	 → 	 quae
# gerunt 	 → 	 gerunt
# civitates 	 → 	 civitates
# partim 	 → 	 partim
# quae 	 → 	 quae
# Tyranni 	 → 	 Tyranni
# cum 	 → 	 cum
# his 	 → 	 his
# quos 	 → 	 quos
# oppresserunt 	 → 	 oppresserunt
# Ex 	 → 	 Ex
# his 	 → 	 his
# sane 	 → 	 sane
# bellis 	 → 	 bellis
# quidquid 	 → 	 quidquid
# est 	 → 	 est
# malorum 	 → 	 malorum
# ea 	 → 	 ea
# Tyrannus 	 → 	 Tyrannus
# cum 	 → 	 cum
# ctvitatibus 	 → 	 civitatibus
# habet 	 → 	 habet
# communia 	 → 	 communia
# eo 	 → 	 eo
# quod 	 → 	 quod
# necesse 	 → 	 necesse
# sit 	 → 	 sit
# et 	 → 	 et
# Tyrannum 	 → 	 Tyrannum
# et 	 → 	 et
# civitatem 	 → 	 civitatem
# tum 	 → 	 tum
# in 	 → 	 in
# armis 	 → 	 armis
# esse 	 → 	 esse
# tum 	 → 	 tum
# excubias 	 → 	 excubias
# agere 	 → 	 agere
# tum 	 → 	 tum
# periclitari. 	 → 	 periclitari
# Et 	 → 	 Et
# si 	 → 	 si
# quid 	 → 	 quid
# triste 	 → 	 triste
# acciderit 	 → 	 acciderit
# victis 	 → 	 victis
# utrique 	 → 	 utrique
# super 	 → 	 super
# hoc 	 → 	 hoc
# discruciantur 	 → 	 discutiantur
# Atque 	 → 	 Atque
# hactenus 	 → 	 hactenus
# quidem 	 → 	 quidem
# par 	 → 	 par
# est 	 → 	 est
# illis 	 → 	 illis
# bellorum 	 → 	 bellorum
# conditio 	 → 	 conditio
# Caeterum 	 → 	 Caeterum
# quae 	 → 	 quae
# jucundaaccidunt 	 → 	 jucundaaccidunt
# civitatibus 	 → 	 civitatibus
# cum 	 → 	 cum
# civitatibus 	 → 	 civitatibus
# bellum 	 → 	 bellum
# gerentibus 	 → 	 gerentibus
# ea 	 → 	 ea
# Tyranni 	 → 	 Tyranni
# non 	 → 	 non
# habent 	 → 	 habent
# Nam 	 → 	 Nam
# civitates 	 → 	 civitates
# profecto 	 → 	 profecto
# si 	 → 	 si
# quando 	 → 	 quando
# devicerint 	 → 	 deficerent
# hostes 	 → 	 hostes
# haud 	 → 	 haud
# dictu 	 → 	 dictu
# facile 	 → 	 facile
# sit 	 → 	 sit
# quantam 	 → 	 quantam
# capiant 	 → 	 capiant
# voluptatem 	 → 	 voluptatem
# dum 	 → 	 dum
# inimicos 	 → 	 inimicos
# cogunt 	 → 	 cogunt
# terga 	 → 	 terga
# vertere 	 → 	 vertere
# quantam 	 → 	 quantam
# dum 	 → 	 dum
# fugientes 	 → 	 fugientes
# insequuntur 	 → 	 insequuntur
# quantam 	 → 	 quantam
# dum 	 → 	 dum
# trucidant 	 → 	 trucidant
# hostes 	 → 	 hostes
# Quam 	 → 	 Quam
# vero 	 → 	 vero
# exsultant 	 → 	 exsultant
# ac 	 → 	 ac
# gestiunt 	 → 	 gestiunt
# de 	 → 	 de
# rebus 	 → 	 rebus
# praeclare 	 → 	 praeclare
# gestis 	 → 	 gestis
# Quam 	 → 	 Quam
# illustrem 	 → 	 illustrem
# reserunt 	 → 	 referunt
# gloriam 	 → 	 gloriam
# Quam 	 → 	 Quam
# gaudent 	 → 	 gaudent
# arbitrantes 	 → 	 arbitrantes
# ipsorum 	 → 	 ipsorum
# opera 	 → 	 opera
# Rempublicam 	 → 	 Rempublicam
# auctam 	 → 	 auctam
# esse 	 → 	 esse
# Tum 	 → 	 Tum
# illorum 	 → 	 illorum
# quisque 	 → 	 quisque
# jactat 	 → 	 jactat
# se 	 → 	 se
# et 	 → 	 et
# consilii 	 → 	 consilii
# fuisse 	 → 	 fuisse
# participem 	 → 	 participem
# et 	 → 	 et
# quamplurimos 	 → 	 quamplurimos
# dedisse 	 → 	 dedisse
# neci 	 → 	 neci
# Difficile 	 → 	 Difficile
# vero 	 → 	 vero
# reperias 	 → 	 reperias
# ubi 	 → 	 ubi
# non 	 → 	 non
# etiam 	 → 	 etiam
# adfingant 	 → 	 adfirmant
# aliquid 	 → 	 aliquid
# narrantes 	 → 	 narrantes
# se 	 → 	 se
# plures 	 → 	 plures
# occidisse 	 → 	 occidisse
# quam 	 → 	 quam
# revera 	 → 	 revera
# perierint 	 → 	 perierint
# Usque 	 → 	 Usque
# adeo 	 → 	 adeo
# res 	 → 	 res
# istisvidetur 	 → 	 istisvidetur
# speciosa 	 → 	 speciosa
# vicisse 	 → 	 vicisse
# plurimos 	 → 	 plurimos
# At 	 → 	 At
# Tyrannus 	 → 	 Tyrannus
# ubi 	 → 	 ubi
# suspicatur 	 → 	 suspicatur
# aut 	 → 	 aut
# etiam 	 → 	 etiam
# re 	 → 	 re
# compertum 	 → 	 compertum
# habet 	 → 	 habet
# esse 	 → 	 esse
# qui 	 → 	 qui
# ipsi 	 → 	 ipsi
# reluctentur 	 → 	 reluctetur
# postquam 	 → 	 postquam
# occiderit 	 → 	 occiderit
# illos 	 → 	 illos
# novit 	 → 	 novit
# non 	 → 	 non
# totam 	 → 	 totam
# civitatem 	 → 	 civitatem
# in 	 → 	 in
# ipsius 	 → 	 ipsius
# partes 	 → 	 partes
# concessuram 	 → 	 concessurum
# neque 	 → 	 neque
# nescit 	 → 	 nescit
# quod 	 → 	 quod
# jam 	 → 	 jam
# paucioribus 	 → 	 paucioribus
# sitimperaturus 	 → 	 sitimperaturus
# eoque 	 → 	 eoque
# non 	 → 	 non
# potest 	 → 	 potest
# hilaris 	 → 	 hilaris
# esse 	 → 	 esse
# neque 	 → 	 neque
# se 	 → 	 se
# jactat 	 → 	 jactat
# de 	 → 	 de
# facinore 	 → 	 facinore
# sed 	 → 	 sed
# rem 	 → 	 rem
# elevat 	 → 	 elevat
# quantum 	 → 	 quantum
# potest 	 → 	 potest
# excusarque 	 → 	 excusare
# sese 	 → 	 sese
# simul 	 → 	 simul
# hoc 	 → 	 hoc
# agens 	 → 	 agens
# ut 	 → 	 ut
# ne 	 → 	 ne
# per 	 → 	 per
# injuriam 	 → 	 injuriam
# fecisse 	 → 	 fecisse
# videatur 	 → 	 videatur
# Adeo 	 → 	 Adeo
# nec 	 → 	 nec
# ipsi 	 → 	 ipsi
# quod 	 → 	 quod
# geritur 	 → 	 geritur
# honestum 	 → 	 honestum
# esse 	 → 	 esse
# videtur 	 → 	 videtur
# Deinde 	 → 	 Deinde
# occisis 	 → 	 occisis
# quos 	 → 	 quos
# s 	 → 	 s
# nihilo 	 → 	 nihilo
# magis 	 → 	 magis
# ob 	 → 	 ob
# id 	 → 	 id
# securus 	 → 	 securus
# est 	 → 	 est
# quin 	 → 	 quin
# potius 	 → 	 potius
# jam 	 → 	 jam
# magis 	 → 	 magis
# sibi 	 → 	 sibi
# cavet 	 → 	 cavet
# quamantea 	 → 	 quamantea
# Ac 	 → 	 Ac
# Tyrannus 	 → 	 Tyrannus
# quidem 	 → 	 quidem
# tale 	 → 	 tale
# bellum 	 → 	 bellum
# habet 	 → 	 habet
# perpetuo 	 → 	 perpetuo
# quod 	 → 	 quod
# ipse 	 → 	 ipse
# in 	 → 	 in
# me 	 → 	 me
# perspicuum 	 → 	 perspicuum
# facio 	 → 	 facio
# Nunc 	 → 	 Nunc
# porro 	 → 	 porro
# considera 	 → 	 considera
# amicitias 	 → 	 amicitias
# quarum 	 → 	 quarum
# m 	 → 	 m
# sunt 	 → 	 sunt
# Tyranni 	 → 	 Tyranni
# Primum 	 → 	 Primum
# enim 	 → 	 enim
# quoniam 	 → 	 quoniam
# magnum 	 → 	 magnum
# Hu 	 → 	 Hu
# gimini 	 → 	 gemini
# arbitror 	 → 	 arbitror
# eos 	 → 	 eos
# plus 	 → 	 plus
# boni 	 → 	 boni
# capere 	 → 	 capere
# qui 	 → 	 qui
# sunt 	 → 	 sunt
# familiares 	 → 	 familiares
# quam 	 → 	 quam
# vos 	 → 	 vos
# ipsos 	 → 	 ipsos
# quandoquidem 	 → 	 quandoquidem
# et 	 → 	 et
# ingratos 	 → 	 ingratos
# odores 	 → 	 odores
# non 	 → 	 non
# sentit 	 → 	 sentit
# is 	 → 	 is
# qui 	 → 	 qui
# se 	 → 	 se
# illis 	 → 	 illis
# explevit 	 → 	 explevit
# sed 	 → 	 sed
# hi 	 → 	 hi
# potius 	 → 	 potius
# qui 	 → 	 qui
# ad 	 → 	 ad
# eum 	 → 	 eum
# qui 	 → 	 qui
# devoravit 	 → 	 devoravit
# accedunt 	 → 	 accedunt
# Itidem 	 → 	 Itidem
# inquit 	 → 	 inquit
# Hieron 	 → 	 Hieron
# usu 	 → 	 usu
# venit 	 → 	 venit
# incibis 	 → 	 incipis
# Cui 	 → 	 Cui
# perpetuo 	 → 	 perpetuo
# suppetit 	 → 	 suppetit
# omne 	 → 	 omne
# genus 	 → 	 genus
# epularum 	 → 	 epularum
# nihil 	 → 	 nihil
# illorum 	 → 	 illorum
# sumit 	 → 	 sumit
# cum 	 → 	 cum
# appetentia 	 → 	 appetentis
# Verum 	 → 	 Verum
# cui 	 → 	 cui
# quid 	 → 	 quid
# raro 	 → 	 raro
# contingit 	 → 	 contingit
# is 	 → 	 is
# demum 	 → 	 demum
# est 	 → 	 est
# qui 	 → 	 qui
# cum 	 → 	 cum
# voluptate 	 → 	 voluptate
# satiatur 	 → 	 satiatur
# si 	 → 	 si
# quidilIi 	 → 	 quidilIi
# objiciatur 	 → 	 obiciatur
# Solae 	 → 	 Solae
# igitur 	 → 	 igitur
# inquit 	 → 	 inquit
# Simonides 	 → 	 Simonides
# V 	 → 	 V
# enereae 	 → 	 andreae
# rei 	 → 	 rei
# delectationes 	 → 	 delectationes
# veniunt 	 → 	 veniunt
# in 	 → 	 in
# periculum 	 → 	 periculum
# ne 	 → 	 ne
# videantur 	 → 	 videantur
# regni 	 → 	 regni
# cupiditatem 	 → 	 cupiditatem
# adferre 	 → 	 adferre
# Hic 	 → 	 Hic
# enim 	 → 	 enim
# solis 	 → 	 solis
# vobis 	 → 	 vobis
# licet 	 → 	 licet
# ut 	 → 	 ut
# quidque 	 → 	 quidque
# Visum 	 → 	 Visum
# fuerit 	 → 	 fuerit
# pulcerrimum 	 → 	 pulcerrimum
# cum 	 → 	 cum
# eo 	 → 	 eo
# congredi 	 → 	 congredi
# Nunc 	 → 	 Nunc
# demum 	 → 	 demum
# inquit 	 → 	 inquit
# Hieron 	 → 	 Hieron
# commemorasti 	 → 	 commemorati
# in 	 → 	 in
# quo 	 → 	 quo
# citra 	 → 	 citra
# controversiam 	 → 	 controversiam
# inferiores 	 → 	 inferiores
# sumus 	 → 	 sumus
# hominibus 	 → 	 hominibus
# privatis 	 → 	 privatis
# Principio 	 → 	 Principio
# namque 	 → 	 namque
# pulcerrimum 	 → 	 pulcerrimum
# esse 	 → 	 esse
# videtur 	 → 	 videtur
# uxorem 	 → 	 uxorem
# ducere 	 → 	 ducere
# ex 	 → 	 ex
# his 	 → 	 his
# qui 	 → 	 qui
# tum 	 → 	 tum
# opibus 	 → 	 opibus
# tum 	 → 	 tum
# potentia 	 → 	 potentia
# praecellunt 	 → 	 praecellunt
# eaque 	 → 	 eaque
# res 	 → 	 res
# putatur 	 → 	 putatur
# adjungere 	 → 	 adjungere
# cum 	 → 	 cum
# voluptate 	 → 	 voluptate
# dignitatis 	 → 	 dignitatis
# nonnihil 	 → 	 nonnihil
# ei 	 → 	 ei
# qui 	 → 	 qui
# duxit 	 → 	 duxit
# Proximum 	 → 	 Proximum
# autem 	 → 	 autem
# est 	 → 	 est
# ex 	 → 	 ex
# paribus 	 → 	 paribus
# uxorem 	 → 	 uxorem
# adsciscere 	 → 	 adsciscere
# Caeterum 	 → 	 Caeterum
# cum 	 → 	 cum
# inferioribus 	 → 	 inferioribus
# contractum 	 → 	 contractum
# matrimonium 	 → 	 matrimonium
# prorsus 	 → 	 prorsus
# contemtum 	 → 	 contemtum
# et 	 → 	 et
# injucundum 	 → 	 iniucundum
# habetur 	 → 	 habetur
# At 	 → 	 At
# Regi 	 → 	 Regi
# nisi 	 → 	 nisi
# peregrinam 	 → 	 peregrinam
# ducat 	 → 	 ducat
# ex 	 → 	 ex
# inferioribus 	 → 	 inferioribus
# ducat 	 → 	 ducat
# necesse 	 → 	 necesse
# ...
# omnes 	 → 	 omnes
# Ac 	 → 	 Ac
# tutum 	 → 	 tutum
# tibi 	 → 	 tibi
# erit 	 → 	 erit
# si 	 → 	 si
# quo 	 → 	 quo
# voles 	 → 	 voles
# ad 	 → 	 ad
# spectaculum 	 → 	 spectaculum
# proficisci 	 → 	 proficisci
# licebit 	 → 	 licebit
# et 	 → 	 et
# hac 	 → 	 hac
# ipsa 	 → 	 ipsa
# inurbe 	 → 	 iure
# manenti 	 → 	 manenti
# spectaculis 	 → 	 spectaculis
# frui 	 → 	 frui
# Semper 	 → 	 Semper
# enim 	 → 	 enim
# apud 	 → 	 apud
# te 	 → 	 te
# fuerit 	 → 	 fuerit
# conventus 	 → 	 conventus
# corum 	 → 	 corum
# qui 	 → 	 qui
# cupiunt 	 → 	 cupiunt
# ostentare 	 → 	 ostentare
# si 	 → 	 si
# quis 	 → 	 quis
# quid 	 → 	 quid
# pulcri 	 → 	 pulcra
# bonive 	 → 	 bonisve
# habeat 	 → 	 habeat
# quum 	 → 	 quum
# hi 	 → 	 hi
# cupiant 	 → 	 cupiant
# etiam 	 → 	 etiam
# inservire 	 → 	 inservire
# Praeterea 	 → 	 Praeterea
# quisquis 	 → 	 quisquis
# adfuerit 	 → 	 adfuerit
# tibi 	 → 	 tibi
# tuarum 	 → 	 tuarum
# parF 	 → 	 pars
# tium 	 → 	 tium
# erit 	 → 	 erit
# rursus 	 → 	 rursus
# qui 	 → 	 qui
# abest 	 → 	 abest
# te 	 → 	 te
# videre 	 → 	 videre
# concupiscet 	 → 	 concupiscet
# ut 	 → 	 ut
# non 	 → 	 non
# solum 	 → 	 solum
# diligaris 	 → 	 diligatis
# ab 	 → 	 ab
# hominibus 	 → 	 hominibus
# verum 	 → 	 verum
# etiam 	 → 	 etiam
# ameris 	 → 	 ameris
# Porro 	 → 	 Porro
# formas 	 → 	 formas
# eximias 	 → 	 eximias
# non 	 → 	 non
# oportet 	 → 	 oportet
# abs 	 → 	 abs
# te 	 → 	 te
# tentari 	 → 	 tentari
# sed 	 → 	 sed
# quum 	 → 	 quum
# solliciteris 	 → 	 sollicitis
# a 	 → 	 ad
# formosis 	 → 	 formosis
# ipse 	 → 	 ipse
# serendum 	 → 	 serendum
# erit 	 → 	 erit
# Metum 	 → 	 Metum
# autem 	 → 	 autem
# adeo 	 → 	 adeo
# nullum 	 → 	 nullum
# habiturus 	 → 	 habiturus
# es 	 → 	 es
# ut 	 → 	 ut
# aliis 	 → 	 aliis
# potius 	 → 	 potius
# metum 	 → 	 metum
# ac 	 → 	 ac
# sollicitudinem 	 → 	 sollicitudinem
# injecturus 	 → 	 inuenturus
# sis 	 → 	 sis
# ne 	 → 	 ne
# quid 	 → 	 quid
# tibi 	 → 	 tibi
# accidat 	 → 	 accidat
# quod 	 → 	 quod
# nolint 	 → 	 nolint
# Quin 	 → 	 Quin
# et 	 → 	 et
# habiturus 	 → 	 habiturus
# es 	 → 	 es
# tuos 	 → 	 tuos
# ultro 	 → 	 ultro
# parentes 	 → 	 parentes
# imperatis 	 → 	 imperatis
# videbisque 	 → 	 vidensque
# illos 	 → 	 illos
# ex 	 → 	 ex
# animo 	 → 	 animo
# tui 	 → 	 tui
# curam 	 → 	 curam
# gerere 	 → 	 gerere
# Quod 	 → 	 Quod
# si 	 → 	 si
# quid 	 → 	 quid
# inciderit 	 → 	 inciderit
# periculi 	 → 	 periculi
# non 	 → 	 non
# solum 	 → 	 solum
# videbis 	 → 	 videbis
# illos 	 → 	 illos
# pugnae 	 → 	 pugnae
# socios 	 → 	 socios
# verum 	 → 	 verum
# etiam 	 → 	 etiam
# propugnatores 	 → 	 propugnatores
# Multis 	 → 	 Multis
# quidem 	 → 	 quidem
# muneribus 	 → 	 muneribus
# etiam 	 → 	 etiam
# ultro 	 → 	 ultro
# delatis 	 → 	 delatis
# honoraberis 	 → 	 honorabilis
# non 	 → 	 non
# tamen 	 → 	 tamen
# egebis 	 → 	 egeris
# cuicumque 	 → 	 cuicumque
# tibi 	 → 	 tibi
# bene 	 → 	 bene
# volenti 	 → 	 volenti
# haec 	 → 	 haec
# impertieris 	 → 	 impertiri
# quum 	 → 	 quum
# omnes 	 → 	 omnes
# habiturus 	 → 	 habiturus
# sis 	 → 	 sis
# tibi 	 → 	 tibi
# de 	 → 	 de
# tuis 	 → 	 tuis
# est 	 → 	 est
# Qua 	 → 	 Qua
# quidem 	 → 	 quidem
# re 	 → 	 re
# non 	 → 	 non
# alia 	 → 	 alia
# est 	 → 	 est
# sarcina 	 → 	 sarcina
# civibus 	 → 	 civibus
# gravior 	 → 	 gravior
# Non 	 → 	 Non
# enim 	 → 	 enim
# hos 	 → 	 hos
# solum 	 → 	 solum
# putant 	 → 	 putant
# aequari 	 → 	 aequari
# Tyrannis 	 → 	 Tyrannis
# honore 	 → 	 honore
# verum 	 → 	 verum
# etiam 	 → 	 etiam
# rapinae 	 → 	 rapinae
# causa 	 → 	 causa
# credunt 	 → 	 credunt
# ali 	 → 	 ali
# His 	 → 	 His
# ita 	 → 	 ita
# respondit 	 → 	 respondit
# Simonides 	 → 	 Simonides
# At 	 → 	 At
# emm 	 → 	 eum
# non 	 → 	 non
# dico 	 → 	 dico
# o 	 → 	 o
# Hieron 	 → 	 Hieron
# harum 	 → 	 harum
# omnium 	 → 	 omnium
# rerum 	 → 	 rerum
# curam 	 → 	 curam
# non 	 → 	 non
# esse 	 → 	 esse
# habendam 	 → 	 habendam
# Attamen 	 → 	 Attamen
# functiones 	 → 	 functiones
# mihividentur 	 → 	 mihividentur
# aliae 	 → 	 aliae
# prorsus 	 → 	 prorsus
# in 	 → 	 in
# odium 	 → 	 odium
# adducere 	 → 	 adducere
# aliae 	 → 	 aliae
# rursus 	 → 	 rursus
# cum 	 → 	 cum
# gratia 	 → 	 gratia
# benevolentiaque 	 → 	 benevolentiaeque
# peragi 	 → 	 peragi
# Itaque 	 → 	 Itaque
# docere 	 → 	 docere
# quae 	 → 	 quae
# sunt 	 → 	 sunt
# optima 	 → 	 optima
# et 	 → 	 et
# eos 	 → 	 eos
# qui 	 → 	 qui
# ea 	 → 	 ea
# pulcerrime 	 → 	 pulcherrime
# praestant 	 → 	 praestant
# laudibus 	 → 	 laudibus
# et 	 → 	 et
# honoribus 	 → 	 honoribus
# adficere 	 → 	 adficere
# haec 	 → 	 haec
# quidem 	 → 	 quidem
# functio 	 → 	 functio
# cum 	 → 	 cum
# benevoIentia 	 → 	 benevolentia
# conjuncta 	 → 	 conjuncta
# est 	 → 	 est
# Caeterum 	 → 	 Caeterum
# qui 	 → 	 qui
# secus 	 → 	 secus
# quam 	 → 	 quam
# oportet 	 → 	 oportet
# agit 	 → 	 agit
# quidpiam 	 → 	 quidpiam
# hunc 	 → 	 hunc
# convitiis 	 → 	 convitiis
# afficere 	 → 	 afficere
# cogere 	 → 	 cogere
# mulctam 	 → 	 mulctam
# dicere 	 → 	 dicere
# punireque 	 → 	 puniretur
# nam 	 → 	 nam
# et 	 → 	 et
# haec 	 → 	 haec
# facere 	 → 	 facere
# necessitas 	 → 	 necessitas
# est 	 → 	 est
# cum 	 → 	 cum
# odio 	 → 	 odio
# malevolentiaque 	 → 	 malevolentiae
# conjuncta 	 → 	 conjuncta
# sunt 	 → 	 sunt
# Censeo 	 → 	 Censeo
# itaque 	 → 	 itaque
# viro 	 → 	 viro
# Principi 	 → 	 Principi
# sic 	 → 	 sic
# agendum 	 → 	 agendum
# ut 	 → 	 ut
# si 	 → 	 si
# quid 	 → 	 quid
# egeat 	 → 	 egeat
# coactione 	 → 	 coactione
# hoc 	 → 	 hoc
# aliis 	 → 	 aliis
# exsequendum 	 → 	 exsequendum
# deleget 	 → 	 deleget
# caeterum 	 → 	 caeterum
# quum 	 → 	 quum
# praemia 	 → 	 praemia
# reddenda 	 → 	 reddenda
# sunt 	 → 	 sunt
# his 	 → 	 his
# qui 	 → 	 qui
# rem 	 → 	 rem
# bene 	 → 	 bene
# gesserunt 	 → 	 gesserunt
# id 	 → 	 id
# per 	 → 	 per
# se 	 → 	 se
# ipsum 	 → 	 ipsum
# faciat 	 → 	 faciat
# Quod 	 → 	 Quod
# autem 	 → 	 autem
# haec 	 → 	 haec
# recte 	 → 	 recte
# habent 	 → 	 habent
# testatur 	 → 	 testatur
# publica 	 → 	 publica
# consuetudo 	 → 	 consuetudo
# Quoties 	 → 	 Quoties
# volumus 	 → 	 volumus
# nobis 	 → 	 nobis
# musicum 	 → 	 musicum
# certamen 	 → 	 certamen
# exhiberi 	 → 	 exhiberi
# praemia 	 → 	 praemia
# quidem 	 → 	 quidem
# proponit 	 → 	 proponit
# Princeps 	 → 	 Princeps
# caeterum 	 → 	 caeterum
# eos 	 → 	 eos
# in 	 → 	 in
# unum 	 → 	 unum
# coendi 	 → 	 colendi
# negotium 	 → 	 negotium
# datur 	 → 	 datur
# choragis 	 → 	 choris
# quemadmodum 	 → 	 quemadmodum
# aliis 	 → 	 aliis
# et 	 → 	 et
# nꝶ 	 → 	 ne
# vimque 	 → 	 vimque
# adhibendi 	 → 	 adhibendi
# eis 	 → 	 eis
# qui 	 → 	 qui
# minus 	 → 	 minus
# recte 	 → 	 recte
# se 	 → 	 se
# gerunt 	 → 	 gerunt
# partes 	 → 	 partes
# delegantur 	 → 	 delegantur
# Ita 	 → 	 Ita
# fit 	 → 	 fit
# protinus 	 → 	 protinus
# ut 	 → 	 ut
# in 	 → 	 in
# his 	 → 	 his
# quod 	 → 	 quod
# gratiosum 	 → 	 gratiosum
# est 	 → 	 est
# per 	 → 	 per
# Principem 	 → 	 Principem
# sit 	 → 	 sit
# factum 	 → 	 factum
# quod 	 → 	 quod
# vero 	 → 	 vero
# contra 	 → 	 contra
# peralios 	 → 	 operarios
# Quid 	 → 	 Quid
# igitur 	 → 	 igitur
# vetat 	 → 	 vetat
# et 	 → 	 et
# alias 	 → 	 alias
# functiones 	 → 	 functiones
# quae 	 → 	 quae
# ad 	 → 	 ad
# prohibendos 	 → 	 prohibendos
# homines 	 → 	 homines
# pertinent 	 → 	 pertinent
# simili 	 → 	 simili
# modo 	 → 	 modo
# peragi 	 → 	 peragi
# Nam 	 → 	 Nam
# Respublicae 	 → 	 reipublicae
# omnes 	 → 	 omnes
# divisae 	 → 	 divisae
# sunt 	 → 	 sunt
# aliae 	 → 	 aliae
# per 	 → 	 per
# tribus 	 → 	 tribus
# aliae 	 → 	 aliae
# per 	 → 	 per
# classes 	 → 	 classes
# aliae 	 → 	 aliae
# per 	 → 	 per
# manipulos 	 → 	 manipulos
# Principes 	 → 	 Principes
# autem 	 → 	 autem
# singulis 	 → 	 singulis
# partibus 	 → 	 partibus
# praesident 	 → 	 praesident
# Itaque 	 → 	 Itaque
# si 	 → 	 si
# quis 	 → 	 quis
# quemadmodum 	 → 	 quemadmodum
# fit 	 → 	 fit
# in 	 → 	 in
# choris 	 → 	 choris
# ita 	 → 	 ita
# his 	 → 	 his
# quoque 	 → 	 quoque
# proponat 	 → 	 proponat
# praemia 	 → 	 praemia
# tum 	 → 	 tum
# ob 	 → 	 ob
# egregiam 	 → 	 egregiam
# armaturam 	 → 	 armaturam
# tum 	 → 	 tum
# ob 	 → 	 ob
# pulcre 	 → 	 pulcre
# servatum 	 → 	 servatum
# ordinem 	 → 	 ordinem
# tum 	 → 	 tum
# ob 	 → 	 ob
# equitandi 	 → 	 equitandi
# peritiam 	 → 	 peritiam
# tum 	 → 	 tum
# ob 	 → 	 ob
# virtutem 	 → 	 virtutem
# in 	 → 	 in
# bello 	 → 	 bello
# praestitam 	 → 	 praestitam
# tum 	 → 	 tum
# ob 	 → 	 ob
# justitiam 	 → 	 justitiam
# in 	 → 	 in
# conventis 	 → 	 conventis
# verisimile 	 → 	 verisimile
# est 	 → 	 est
# haec 	 → 	 haec
# quoque 	 → 	 quoque
# cuncta 	 → 	 cuncta
# acrius 	 → 	 acrius
# exercenda 	 → 	 exercenda
# si 	 → 	 si
# adsit 	 → 	 adsit
# contentio 	 → 	 contentio
# vincendique 	 → 	 vendendique
# studium 	 → 	 studium
# Ac 	 → 	 Ac
# per 	 → 	 per
# Jovem 	 → 	 Jovem
# citius 	 → 	 citius
# impelluntur 	 → 	 impelluntur
# quocumque 	 → 	 quocumque
# opus 	 → 	 opus
# est 	 → 	 est
# qui 	 → 	 qui
# honoris 	 → 	 honoris
# suntavidi 	 → 	 suntavidi
# citiusque 	 → 	 citiusque
# conferrent 	 → 	 conferrent
# pecuniam 	 → 	 pecuniam
# si 	 → 	 si
# quando 	 → 	 quando
# pecuniam 	 → 	 pecuniam
# exigat 	 → 	 exigat
# occasio 	 → 	 occasio
# Et 	 → 	 Et
# quod 	 → 	 quod
# est 	 → 	 est
# omnium 	 → 	 omnium
# utilissimum 	 → 	 utilissimum
# id 	 → 	 id
# minime 	 → 	 minime
# tamen 	 → 	 tamen
# usitatum 	 → 	 usitatum
# est 	 → 	 est
# ut 	 → 	 ut
# per 	 → 	 per
# certamen 	 → 	 certamen
# exerceatur 	 → 	 exerceatur
# agricultura 	 → 	 agricultura
# Haec 	 → 	 Haec
# nimirum 	 → 	 nimirum
# est 	 → 	 est
# cui 	 → 	 cui
# multum 	 → 	 multum
# accesserit 	 → 	 accesserit
# si 	 → 	 si
# quis 	 → 	 quis
# per 	 → 	 per
# agros 	 → 	 agros
# ac 	 → 	 ac
# vicos 	 → 	 vicos
# praemia 	 → 	 praemia
# constituat 	 → 	 constituat
# his 	 → 	 his
# qui 	 → 	 qui
# quam 	 → 	 quam
# optime 	 → 	 optime
# terram 	 → 	 terram
# excoluerint 	 → 	 coluerint
# iisque 	 → 	 iisque
# qui 	 → 	 qui
# ex 	 → 	 ex
# civibus 	 → 	 civibus
# maxime 	 → 	 maxime
# in 	 → 	 in
# hancrem 	 → 	 honorem
# incubuerint 	 → 	 incubuerint
# is 	 → 	 is
# multa 	 → 	 multa
# bonaReipublicae 	 → 	 bonaReipublicae
# praestiterit 	 → 	 praestiterit
# Quandoquidem 	 → 	 Quandoquidem
# et 	 → 	 et
# crescent 	 → 	 crescent
# Reipublicae 	 → 	 Reipublicae
# proventus 	 → 	 proventus
# et 	 → 	 et
# sobrietas 	 → 	 sobrietas
# occupatos 	 → 	 occupatos
# magis 	 → 	 magis
# comitabitur 	 → 	 comitabitur
# et 	 → 	 et
# operi 	 → 	 operi
# intentis 	 → 	 intentis
# minus 	 → 	 minus
# orietur 	 → 	 orietur
# scelerum 	 → 	 scelerum
# Quod 	 → 	 Quod
# si 	 → 	 si
# quid 	 → 	 quid
# etiam 	 → 	 etiam
# negociatio 	 → 	 negotiatio
# conducit 	 → 	 conducit
# Reipublicae 	 → 	 Reipublicae
# honos 	 → 	 honos
# habitus 	 → 	 habitus
# ei 	 → 	 ei
# qui 	 → 	 qui
# hanc 	 → 	 hanc
# potissimum 	 → 	 potissimum
# exercuerit 	 → 	 exercuerit
# esficiet 	 → 	 efficiet
# ut 	 → 	 ut
# plures 	 → 	 plures
# adfluant 	 → 	 affluant
# qui 	 → 	 qui
# merces 	 → 	 merces
# importent 	 → 	 important
# Jam 	 → 	 Jam
# si 	 → 	 si
# et 	 → 	 et
# illi 	 → 	 illi
# honos 	 → 	 honos
# habeatur 	 → 	 habeatur
# qui 	 → 	 qui
# Reipublicae 	 → 	 Reipublicae
# utilitatem 	 → 	 utilitatem
# quampiam 	 → 	 quampiam
# citra 	 → 	 citra
# cujusquam 	 → 	 cujusquam
# dolorem 	 → 	 dolorem
# excogitarit 	 → 	 excogitavit
# ne 	 → 	 ne
# haec 	 → 	 haec
# quidem 	 → 	 quidem
# cura 	 → 	 cura
# cessaret 	 → 	 cessaret
# Atque 	 → 	 Atque
# ut 	 → 	 ut
# sermonem 	 → 	 sermonem
# in 	 → 	 in
# pauca 	 → 	 pauca
# conferam 	 → 	 conferam
# si 	 → 	 si
# cunctis 	 → 	 cunctis
# eset 	 → 	 eset
# perspicuum 	 → 	 perspicuum
# noncariturum 	 → 	 noncariturum
# praemio 	 → 	 praemio
# quisquis 	 → 	 quisquis
# boni 	 → 	 boni
# quidpiam 	 → 	 quidpiam
# invexerit 	 → 	 invenerit
# Reipublicae 	 → 	 Reipublicae
# plurimos 	 → 	 plurimos
# ea 	 → 	 ea
# res 	 → 	 res
# excitaret 	 → 	 excitaret
# ad 	 → 	 ad
# studium 	 → 	 studium
# inveniendi 	 → 	 inveniendi
# quidpiam 	 → 	 quidpiam
# boni 	 → 	 boni
# Sane 	 → 	 Sane
# quum 	 → 	 quum
# multis 	 → 	 multis
# curae 	 → 	 curae
# est 	 → 	 est
# civitatis 	 → 	 civitatis
# utilitas 	 → 	 utilitas
# fieri 	 → 	 fieri
# non 	 → 	 non
# potest 	 → 	 potest
# quin 	 → 	 quin
# et 	 → 	 et
# plura 	 → 	 plura
# reperiantur 	 → 	 reperiantur
# ingenio 	 → 	 ingenio
# et 	 → 	 et
# obeantur 	 → 	 habeantur
# functione 	 → 	 functione
# Quod 	 → 	 Quod
# si 	 → 	 si
# metuis 	 → 	 metuis
# o 	 → 	 o
# Hieron 	 → 	 Hieron
# ne 	 → 	 ne
# si 	 → 	 si
# multorum 	 → 	 multorum
# nomine 	 → 	 nomine
# praemia 	 → 	 praemia
# proponantur 	 → 	 proponantur
# nimii 	 → 	 nimii
# sumtus 	 → 	 sumus
# exsistant 	 → 	 exsistant
# cogita 	 → 	 cogita
# nullam 	 → 	 nullam
# mercem 	 → 	 mercem
# esse 	 → 	 esse
# magis 	 → 	 magis
# utilem 	 → 	 utilem
# quam 	 → 	 quam
# quae 	 → 	 quae
# ab 	 → 	 ab
# hominibus 	 → 	 hominibus
# praemiis 	 → 	 praemiis
# emitur 	 → 	 emitur
# Vides 	 → 	 Vides
# in 	 → 	 in
# equestribus 	 → 	 equestribus
# gymnicis 	 → 	 gymnici
# ac 	 → 	 ac
# scenicis 	 → 	 scenicis
# certaminibus 	 → 	 certaminibus
# ut 	 → 	 ut
# exigua 	 → 	 exigua
# praemia 	 → 	 praemia
# ad 	 → 	 ad
# magnos 	 → 	 magnos
# sumtus 	 → 	 sumus
# ad 	 → 	 ad
# magnos 	 → 	 magnos
# labores 	 → 	 labores
# multumque 	 → 	 multumque
# studium 	 → 	 studium
# proliciunt 	 → 	 proficiunt
# homines 	 → 	 homines
# Tum 	 → 	 Tum
# Hieron 	 → 	 Hieron
# Ista 	 → 	 Ista
# quidem 	 → 	 quidem
# inquit 	 → 	 inquit
# Simonides 	 → 	 Simonides
# mihi 	 → 	 mihi
# videris 	 → 	 videris
# recte 	 → 	 recte
# dicere 	 → 	 dicere
# Caeterum 	 → 	 Caeterum
# habesne 	 → 	 habesne
# quidquam 	 → 	 quidquam
# quod 	 → 	 quod
# dicas 	 → 	 dicas
# de 	 → 	 de
# stipendiatis 	 → 	 stipendiis
# quo 	 → 	 quo
# minus 	 → 	 minus
# habeamur 	 → 	 habeatur
# ob 	 → 	 ob
# illos 	 → 	 illos
# odio 	 → 	 odio
# an 	 → 	 an
# dices 	 → 	 dices
# Principi 	 → 	 Principi
# qui 	 → 	 qui
# paravit 	 → 	 paravit
# civium 	 → 	 civium
# benevoIentiam 	 → 	 benevolentiam
# nihil 	 → 	 nihil
# jam 	 → 	 jam
# opus 	 → 	 opus
# fore 	 → 	 fore
# satellitio 	 → 	 satellitio
# Ita 	 → 	 Ita
# per 	 → 	 per
# Jovem 	 → 	 Jovem
# inquit 	 → 	 inquit
# Simonides 	 → 	 Simonides
# opus 	 → 	 opus
# tamen 	 → 	 tamen
# suerit 	 → 	 fuerit
# Novi 	 → 	 Novi
# siquidem 	 → 	 siquidem
# quod 	 → 	 quod
# in 	 → 	 in
# equis 	 → 	 equis
# accidere 	 → 	 accidere
# solet 	 → 	 solet
# idem 	 → 	 idem
# usu 	 → 	 usu
# venire 	 → 	 venire
# in 	 → 	 in
# quibusdam 	 → 	 quibusdam
# hominibus 	 → 	 hominibus
# ut 	 → 	 ut
# quo 	 → 	 quo
# copiosius 	 → 	 copiosius
# ipsis 	 → 	 ipsis
# suppetunt 	 → 	 suppetunt
# necessaria 	 → 	 necessaria
# hoc 	 → 	 hoc
# evadant 	 → 	 evadant
# ferociores 	 → 	 ferociores
# Tales 	 → 	 Tales
# igitur 	 → 	 igitur
# magis 	 → 	 magis
# reddit 	 → 	 reddit
# sobrios 	 → 	 sobrios
# metus 	 → 	 metus
# quem 	 → 	 quem
# adferunt 	 → 	 adferunt
# satellites 	 → 	 satellites
# Caeterum 	 → 	 Caeterum
# honestis 	 → 	 honestis
# ac 	 → 	 ac
# bonis 	 → 	 bonis
# nulla 	 → 	 nulla
# ex 	 → 	 ex
# re 	 → 	 re
# mihi 	 → 	 mihi
# videris 	 → 	 videris
# tantum 	 → 	 tantum
# utilitatum 	 → 	 utilitatum
# praestare 	 → 	 praestare
# quantum 	 → 	 quantum
# praestas 	 → 	 praestas
# ex 	 → 	 ex
# satellitio 	 → 	 satellitio
# Nam 	 → 	 Nam
# alis 	 → 	 alis
# haud 	 → 	 haud
# dubie 	 → 	 dubie
# tu 	 → 	 tu
# quidem 	 → 	 quidem
# illos 	 → 	 illos
# tibiipsi 	 → 	 tibiis
# custodes 	 → 	 custodes
# At 	 → 	 At
# jam 	 → 	 jam
# heri 	 → 	 heri
# complures 	 → 	 complures
# a 	 → 	 ad
# servis 	 → 	 servis
# suis 	 → 	 suis
# interempti 	 → 	 interempti
# sunt 	 → 	 sunt
# Profuerit 	 → 	 Profuerit
# igitur 	 → 	 igitur
# unum 	 → 	 unum
# illudin 	 → 	 illudi
# primis 	 → 	 primis
# si 	 → 	 si
# praeceptum 	 → 	 praeceptum
# fuerit 	 → 	 fuerit
# satellitibus 	 → 	 satellitibus
# ut 	 → 	 ut
# perinde 	 → 	 perinde
# quasi 	 → 	 quasi
# essent 	 → 	 essent
# omnium 	 → 	 omnium
# sutellites 	 → 	 satellites
# civium 	 → 	 civium
# ita 	 → 	 ita
# omnibus 	 → 	 omnibus
# essent 	 → 	 essent
# auxilio 	 → 	 auxilio
# si 	 → 	 si
# quid 	 → 	 quid
# tale 	 → 	 tale
# senserint 	 → 	 senserint
# Sunt 	 → 	 Sunt
# autem 	 → 	 autem
# quemadmodum 	 → 	 quemadmodum
# scimus 	 → 	 scimus
# omnes 	 → 	 omnes
# ros 	 → 	 ros
# filios 	 → 	 filios
# vero 	 → 	 vero
# nonaliter 	 → 	 totaliter
# habeas 	 → 	 habeas
# quam 	 → 	 quam
# animam 	 → 	 animam
# tuam 	 → 	 tuam
# huc 	 → 	 huc
# Interim 	 → 	 Interim
# adnitens 	 → 	 nitens
# ut 	 → 	 ut
# hos 	 → 	 hos
# omnes 	 → 	 omnes
# benesicentia 	 → 	 beneficentia
# superes 	 → 	 superes
# Etenim 	 → 	 Etenim
# si 	 → 	 si
# amicos 	 → 	 amicos
# tibi 	 → 	 tibi
# adjunxeris 	 → 	 adiunxeris
# benefaciendo 	 → 	 benefaciendi
# haudquaatibi 	 → 	 haudquaatibi
# poterunt 	 → 	 poterunt
# obsistere 	 → 	 obsistere
# inimici 	 → 	 inimici
# Haec 	 → 	 Haec
# omnia 	 → 	 omnia
# si 	 → 	 si
# praeiteris 	 → 	 praetoris
# illud 	 → 	 illud
# certum 	 → 	 certum
# habeto 	 → 	 habeto
# te 	 → 	 te
# libi 	 → 	 tibi
# paraturum 	 → 	 paraturam
# quo 	 → 	 quo
# non 	 → 	 non
# alia 	 → 	 alia
# inter 	 → 	 inter
# homines 	 → 	 homines
# possesso 	 → 	 possessio
# vel 	 → 	 vel
# pulcrior 	 → 	 pulcrior
# vel 	 → 	 vel
# beatior 	 → 	 beatior
# quandoquidem 	 → 	 quandoquidem
# quum 	 → 	 quum
# felix 	 → 	 felix
# sis 	 → 	 sis
# tamen 	 → 	 tamen
# tibi 	 → 	 tibi
# nullus 	 → 	 nullus
# invidebit 	 → 	 invidebit
# File 116-xenophon_spellcheck.txt saved.

# %% [markdown]
# Ground truth

# %%
with open("Test/OCR Test/GT/Querela Pacis GT.txt", "r", encoding = "utf-8") as text_file:
    gt = text_file.read()

# %%
print("GT length:", len(gt), "OCR transcript length:", len(transcript))
print("Levenshtein:", distance(gt, transcript))
print("Ratio:", ratio(gt, transcript))

# %% [markdown]
# HTML Encoding

# %%
WORK = "116-xenophon"
TITLES = {"116": "Xenophon"}

SRC = f"output/{WORK}_spellcheck.txt"
DEST = f"output/{WORK}.html"

TITLE = TITLES[WORK[:3]]

HEADER = f"""\
<!DOCTYPE html>
<html lang="lat">
<head>
<title>{TITLE}</title>
<meta charset="utf-8">
<link href="https://fonts.googleapis.com/css?family=Noto+Serif:400,700&amp;subset=greek,greek-ext" rel="stylesheet">
<link href="style.css" rel="stylesheet">
</head>
<body>
  <div class="container">
  <nav>&#x2191; <a href="./">Corpus Erasmicum</a></nav>
  <h1 lang="en">{TITLE}</h1>
"""

FOOTER = """\
  </div>
</body>
</html>
"""

with open(SRC, encoding = "utf-8") as f:
    with open(DEST, "w", encoding = "utf-8") as g:
        prev_section = None
        prev_chapter = None
        print(HEADER, file=g)
        for line in f:
            parts = line.strip().split(maxsplit=1)
            ref = parts[0].split(".")
            if len(ref) == 2:
                section = None
                chapter, verse = ref
            if prev_section != section:
                if prev_section is not None:
                    print("   </div>""", file=g)
                    print("   </div>""", file=g)
                print("""   <div class="section">""", file=g)
                prev_section = section
                prev_chapter = None
            if prev_chapter != chapter:
                if prev_chapter is not None: 
                    if prev_chapter == "0":
                        if section is None:
                            print("""    </div>""", file=g)
                    else:
                        print("""    </div>""", file=g)
                if chapter == "0":
                    if section is None:
                        print("""    <div class="preamble">""", file=g)
                else:
                    if chapter == "SB":
                        print("""    <div class="subscription">""", file=g)
                    elif chapter == "EP":
                        print("""    <div class="epilogue">""", file=g)
                    else:
                        print("""    <div class="chapter">""", file=g)

                prev_chapter = chapter
            if chapter == "0" and verse == "0":
                print(f"""    <h2 class="section_title">{parts[1]}</h2>""", file=g)
            elif chapter != "0" and verse == "0":
                print(f"""<h3 class="sub_title">{parts[1]}</h3>""", file=g)
            elif chapter != "0" and verse != "0":
                print(parts[1], file=g)
        print("""    </div>""", file=g)
        if section is not None:
            print("""    </div>""", file=g)
        print(FOOTER, file=g)
